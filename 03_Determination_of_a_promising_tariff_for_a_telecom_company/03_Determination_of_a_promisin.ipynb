# %% [markdown]
# <a id='step1'></a>

# %% [markdown]
# <div style="border:solid lightblue 3px; padding: 20px">
# <b>Илья, привет!</b>
#
# Меня зовут Виталий Мехоношин, и я буду проверять твой проект. Предлагаю общаться на «ты» 😉
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных. Тобой проделана большая работа над проектом, давай сделаем его еще лучше. Ниже ты найдешь мои комментарии. Так же есть несколько правил:<br>
# - <b>Пожалуйста, не перемещай, не изменяй и не удаляй комментарии.</b>
# - У комментариев могут быть приписки <b>V2, V3</b> и т.д., которые соответствуют версии проверки.
# - Еще обрати внимание на цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Комментарий ревьюера:</b>
# Комментарии такого цвета необходимо исправить, без их отработки проект не будет принят.
# </div>
#
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>
# На комментарии такого цвета нужно обязательно обратить внимание. Их не должно быть много.
# </div>
#
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
# Комментарии такого цвета будут содержать лайфхаки, которые смогут улучшить твой верный код, их необязательно исправлять.
# </div>
#
# Предлагаю работать над проектом в диалоге: если ты хочешь ответить на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии вот так:
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %% [markdown]
# <div style="border:solid lightblue 3px; padding: 20px">
# <b>Общий комментарий ревьюера:</b>
#
# У тебя замечательная и очень сильная работа. Хочется отметить ряд моментов, которые меня очень порадовали.
#
# - Оформление проекта. Спасибо тебе большое, что ты уделил этой части проекта особое внимание - ты не представляешь как приятно не рыться в коде и не скролить туды сюды блокнот, чтобы найти какую-нибудь информацию. Каждый заголовок выделен, каждое рассуждение выделено, каждый пункт выделен - просто супер, прям испытал эстетическое удовольствие.
#
# - Подробность рассуждений. Отлично, что ты не удаляешь промежуточные строки кода и наоборот наполняешь проект все возможными проверками и дополнительной визуализацией. Проверка проекта с такими подробными моментами происходит в разы быстрее.
#
# - Оптимизация. Замечательно, что ты оптимизируешь свои действия с помощью создания циклов и дополнительных функций, тем самым, сокращая кол-во строчек кода и причесывая код в более надлежащий вид.
#
# Я постарался оставить максимально подробные советы и лайфхаки по оптимизации и без того, в принципе, очень хорошего кода, но рекомендую в них разобраться и в следующих проектах обязательно применять эти знания.
#
# Так же в проекте есть и моменты, которые следует доработать, а именно:
#
# 1. Комментарий по п.3.2. Произведи, пожалуйста, корректное округление длительно звонков и трафика интернета. Соответствующие пояснения ты найдешь в этом пункте.
# 2. Комментарий по п.3.3.3. Произведи корректное соединение датафреймов. Соответствующие пояснения ты найдешь в этом пункте.
#
# Так же обрати, пожалуйста, внимание на желтые комментарии, там в основном пожелания, но они тоже имеют место быть. Буду ждать твоего исправления😊
# </div>

# %% [markdown]
# <div style="border:solid lightblue 3px; padding: 20px">
# <b>Общий комментарий ревьюера:</b>
#
# Отлично, тебе удалось корректно поработать над всеми комментариями. Так же привел тебе новые корректировки и объяснения, поразбирайся с ними и бери на вооружение в будущем. Проект принят, удачи на следующих спринтах😊
# </div>

# %% [markdown]
# <h1>План проекта<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Постановка-задачи" data-toc-modified-id="Постановка-задачи-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Постановка задачи</a></span></li><li><span><a href="#Получение-данных" data-toc-modified-id="Получение-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Получение данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Обработка пропусков</a></span></li><li><span><a href="#Замена-типа-данных" data-toc-modified-id="Замена-типа-данных-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Замена типа данных</a></span></li><li><span><a href="#Объединение-таблиц.--Количественные-показатели." data-toc-modified-id="Объединение-таблиц.--Количественные-показатели.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Объединение таблиц.  Количественные показатели.</a></span><ul class="toc-item"><li><span><a href="#Определим-количество--звонков-и-израсходованных-минут-разговора-по-месяцам-" data-toc-modified-id="Определим-количество--звонков-и-израсходованных-минут-разговора-по-месяцам--3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Определим количество  звонков и израсходованных минут разговора по месяцам <br></a></span></li><li><span><a href="#Определим-количество--отправленных-сообщений-по-месяцам-" data-toc-modified-id="Определим-количество--отправленных-сообщений-по-месяцам--3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Определим количество  отправленных сообщений по месяцам <br></a></span></li><li><span><a href="#Определим-объем-израсходованного-интернет-трафика-по-месяцам" data-toc-modified-id="Определим-объем-израсходованного-интернет-трафика-по-месяцам-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Определим объем израсходованного интернет-трафика по месяцам<br></a></span></li><li><span><a href="#Определим--помесячную-выручку-с-каждого-пользователя" data-toc-modified-id="Определим--помесячную-выручку-с-каждого-пользователя-3.3.4"><span class="toc-item-num">3.3.4&nbsp;&nbsp;</span>Определим  помесячную выручку с каждого пользователя</a></span></li></ul></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Проведем-исследовательский-анализ-данных-построим-графики-и-гистаграммы-для-получения-ответов-в-поставленной-задаче." data-toc-modified-id="Проведем-исследовательский-анализ-данных-построим-графики-и-гистаграммы-для-получения-ответов-в-поставленной-задаче.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Проведем исследовательский анализ данных построим графики и гистаграммы для получения ответов в поставленной задаче.</a></span></li></ul></li><li><span><a href="#Проверка-гипотез." data-toc-modified-id="Проверка-гипотез.-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проверка гипотез.</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# <a id='step2'></a>

# %% [markdown]
# <br>[**Проектная работа описание задания.**](#step20)<br>

# %% [markdown]
# ***Описание данных*** <br>
#
# `1.Таблица` ___users___ — (информация о пользователях):
# - **tariff_name** — название тарифа
# - **user_id** — уникальный идентификатор пользователя
# - **first_name** — имя пользователя
# - **last_name** — фамилия пользователя
# - **age** — возраст пользователя (годы)
# - **reg_date** — дата подключения тарифа (день, месяц, год)
# - **churn_date** — дата прекращ пользован тарифом (если значение пропущено, то тариф ещё действовал на момент выгрузки данных)
# - **city** — город проживания пользователя
# - **tariff** — название тарифного плана<br>
#
# `2.Таблица` ____calls____ — (информация о звонках):<br>
# - **id** — уникальный номер звонка
# - **call_date** — дата звонка
# - **duration** — длительность звонка в минутах
# - **user_id** — идентификатор пользователя, сделавшего звонок<br>
#
# `3.Таблица` ___messages___ — (информация о сообщениях):<br>
# - **id** — уникальный номер сообщения
# - **message_date** — дата сообщения
# - **user_id** — идентификатор пользователя, отправившего сообщение<br>
#
# `4.Таблица` ___internet___ — (информация об интернет-сессиях):<br>
# - **id** — уникальный номер сессии
# - **mb_used** — объём потраченного за сессию интернет-трафика (в мегабайтах)
# - **session_date** — дата интернет-сессии
# - **user_id** — идентификатор пользователя<br>
#
# `5.Таблица` ___tariffs___ — (информация о тарифах):
# - **tariff_name** — название тарифа
# - **rub_monthly_fee** — ежемесячная абонентская плата в рублях
# - **minutes_included** — количество минут разговора в месяц, включённых в абонентскую плату
# - **messages_included** — количество сообщений в месяц, включённых в абонентскую плату
# - **mb_per_month_included** — объём интернет-трафика, включённого в абонентскую плату (в мегабайтах)
# - **rub_per_minute** — стоимость минуты разговора сверх тарифного пакета (например, если в тарифе 100 минут разговора в месяц, то со 101 минуты будет взиматься плата)
# - **rub_per_message** — стоимость отправки сообщения сверх тарифного пакета
# - **rub_per_gb** — стоимость дополнительного гигабайта интернет-трафика сверх тарифного пакета (1 гигабайт = 1024 мегабайта)
#
# ***Описание тарифов:***
#
# **1.Тариф «Смарт»**
#
#    * Ежемесячная плата: 550 рублей
#    * Включено 500 минут разговора, 50 сообщений и 15 Гб интернет-трафика
#
#    *Стоимость услуг сверх тарифного пакета:*
#    * минута разговора: 3 рубля
#    * сообщение: 3 рубля
#    * 1 Гб интернет-трафика: 200 рублей
#
# **2.Тариф «Ультра»**
#
#    * Ежемесячная плата: 1950 рублей
#    * Включено 3000 минут разговора, 1000 сообщений и 30 Гб интернет-трафика
#
#    *Стоимость услуг сверх тарифного пакета:*
#    * минута разговора: 1 рубль
#    * сообщение: 1 рубль
#    * 1 Гб интернет-трафика: 150 рублей

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Отлично, что добавил описание используемых датасетов. Теперь, любой человек, который увидит твое решение будет хоть немного в курсе того, что происходит.
#
# </div>

# %% [markdown]
# ## Постановка задачи
# [&#10224;](#step1)

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# ---
#  ##                    Определение перспективного тарифа для телеком компании «Мегалайн» <a class="tocSkip">
#
# ### Задача  проекта:<a class="tocSkip">
# - Исследовать и описать поведение клиентов оператора "Мегалайн" по исследуемой выборке из 500 человек с тарифами "Смарт"  и "Ультра". Ответить на вопросы: - Сколько требуется клиентам каждого тарифного плана минут разговора, интернет трафика и количества sms сообщений за один каллендарный месяц. Посчитать среднее количество, дисперсию и стандартное отклонение. Построить гистограммы. Описать распределения.<br>
# - Проверить гипотезы
#     - средняя выручка пользователей тарифов  "Смарт" и"Ультра" отличаются.
#     - средняя выручка пользователей из Москвы  отличается от выручки пользователей из других регионов.<br>
#
# - Результаты исследования оформить  общим выводом.
#
# ### Достичь основной цели:<a class="tocSkip">
#
# - Так как коммерческий департамент компании "Мегалайн"- ставит задачу аналитику,  получить ответ, __какой тарифный план  более выгоден компании__, следовательно это и есть __основная цель проекта__ - проанализировав повдение клиентов, сделать вывод - какой тарифный план  лучше.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Отлично выделены задачи и цели, молодец, что разобрался с использованием `html` разметки. Если хочешь почитать что-нибудь более подробное про оформление markdown ячеек, то посмотри [тут](https://medium.com/analytics-vidhya/the-ultimate-markdown-guide-for-jupyter-notebook-d5e5abf728fd).
#
# </div>

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Получение данных
# [&#10224;](#step1)

# %% [markdown]
# ___Импортируем необходимые для работы библиотеки___

# %%
import pandas as pd # импорт библиотеки pandas
#from pymystem3 import Mystem # pymystem3 импортируется 
#m = Mystem() 
import matplotlib.pyplot as plt #импортируем библиотеку для графиков matplotlib
import numpy as np
import seaborn as sn # подключение графической библиотеки seaborn
import plotly.express as px# функция для создания таблиц и визуализации plotly

# %% [markdown]
# __Прочитаем файлы _.csv и сохраним их в  DataFrame__

# %%
pd.set_option('display.float_format', '{:,.2f}'.format)# вывод без экспонентациальных форм и лишних запятых.
pd.set_option('display.max_columns', None) # вывод всех колонок датасета без урезания.

try: #конструкция try-except помогает выбрать работающий путь к исследуемому файлу 'real_estate_data.csv'
    users = pd.read_csv('/data_set/3telekom/users.csv')# чтение файла с данными с сохранением в df /Работа - Локально/
    calls = pd.read_csv('/data_set/3telekom/calls.csv')# чтение файла с данными с сохранением в df /Работа - Локально/
    messages = pd.read_csv('/data_set/3telekom/messages.csv')# чтение файла с данными с сохранением в df /Работа - Локально/
    internet = pd.read_csv('/data_set/3telekom/internet.csv')# чтение файла с данными с сохранением в df /Работа - Локально/
    tariffs = pd.read_csv('/data_set/3telekom/tariffs.csv')# чтение файла с данными с сохранением в df /Работа - Локально/
except:
    users = pd.read_csv('/datasets/users.csv')# чтение файла с данными с сохранением в df /Работа - сервер Яндекс
    calls = pd.read_csv('/datasets/calls.csv')# чтение файла с данными с сохранением в df /Работа - сервер Яндекс
    messages = pd.read_csv('/datasets/messages.csv')# чтение файла с данными с сохранением в df /Работа - сервер Яндекс
    internet = pd.read_csv('/datasets/internet.csv')# чтение файла с данными с сохранением в df /Работа - сервер Яндекс
    tariffs = pd.read_csv('/datasets/tariffs.csv')# чтение файла с данными с сохранением в df /Работа - сервер Яндекс

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Супер, что разобрался с использованием структуры `try-except` - очень полезная вещь. Так же хочу отметить, что ты даешь вполне адекватные названия датасетам, соответствующие их содержимому - круто.
#
# </div>

# %% [markdown]
# ---

# %% [markdown]
# __Делаем предварительную оценку полученных данных__

# %% [markdown]
# Создадим список полученных таблиц

# %%
df_list = [users, calls , messages, internet, tariffs]
for i in df_list:
    display(i.shape)
# Out:
# (500, 8)
# (202607, 4)
# (123036, 3)
# (149396, 5)
# (2, 8)

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Молодец, что оптимизировал подход к выводу размерности. Не очень только понимаю зачем?
# </div>

# %% [markdown]
# <div style="border:solid light blue 1px; padding: 1px">
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
#   В анализе данных не бывает лишних умозаключений!)) По мне, так годная вещь.  Вспомнил цикл, содал df_list(позже пригодится),
# увидел  и ужаснулся, что ни одна таблица не совпадает по количеству строк).&#128522;
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера V2:</b>
#
# Это да, в анализе всегда все пригождается. Здесь только ты эти данные дальше никак не используешь.
# </div>

# %% [markdown]
# Получили 5 таблиц с разными количесвами строк и столбцов. Рассмотрим полученные данные более детально.

# %% [markdown]
# ---

# %% [markdown]
# `1.Таблица` ___users___ — (информация о пользователях):
# - **tariff_name** — название тарифа
# - **user_id** — уникальный идентификатор пользователя
# - **first_name** — имя пользователя
# - **last_name** — фамилия пользователя
# - **age** — возраст пользователя (годы)
# - **reg_date** — дата подключения тарифа (день, месяц, год)
# - **churn_date** — дата прекращ пользован тарифом (если значение пропущено, то тариф ещё действовал на момент выгрузки данных)
# - **city** — город проживания пользователя
# - **tariff** — название тарифного плана<br>

# %% [markdown]
# Получим  строки таблицы. Для формирования общей картины по df_users.

# %%
users#перевый взгляд на  users
# Out:
#      user_id  age  churn_date         city first_name  last_name    reg_date  \
# 0       1000   52         NaN    Краснодар     Рафаил  Верещагин  2018-05-25
# 1       1001   41         NaN       Москва       Иван       Ежов  2018-11-01
# 2       1002   59         NaN  Стерлитамак    Евгений  Абрамович  2018-06-17
# 3       1003   23         NaN       Москва      Белла   Белякова  2018-08-17
# 4       1004   68         NaN  Новокузнецк    Татьяна   Авдеенко  2018-05-14
# ..       ...  ...         ...          ...        ...        ...         ...
# 495     1495   65         NaN      Иркутск  Авксентий      Фокин  2018-08-28
# 496     1496   36         NaN      Вологда     Трифон     Блохин  2018-01-27
# 497     1497   32         NaN    Челябинск   Каролина     Агеева  2018-10-09
# 498     1498   68  2018-10-25  Владикавказ   Всеволод    Акимчин  2018-07-19
# 499     1499   35         NaN        Пермь     Гектор   Корнилов  2018-09-27
#
#     tariff
# 0    ultra
# 1    smart
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Если тебе не прицнипиален вывод полного кол-ва строк, то пользуйся методом `head` с встроенным значением в 5 строк - код становится аккуратней.
#
# </div>

# %% [markdown]
# <div style="border:solid light blue 1px; padding: 1px">
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Да, про head знаю, но здесь, в самом начале, как-бы и снизу и свероху посмотрел.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера V2:</b>
#
# Хорошо.
# </div>

# %% [markdown]
#  Методом .info() получим  информацию о пропусках и  используемых форматах в исследуемом users

# %%
users.info()#смотрим в каком формате представлены столбцы из users
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   age         500 non-null    int64
#  2   churn_date  38 non-null     object
#  3   city        500 non-null    object
#  4   first_name  500 non-null    object
#  5   last_name   500 non-null    object
#  6   reg_date    500 non-null    object
#  7   tariff      500 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB

# %% [markdown]
# Методом .describe() делаем __числовое описание данных__, выводим основные показатели по исследуемому users

# %%
users.describe()# цифровая оценка данных из users
# Out:
#        user_id    age
# count   500.00 500.00
# mean  1,249.50  46.59
# std     144.48  16.67
# min   1,000.00  18.00
# 25%   1,124.75  32.00
# 50%   1,249.50  46.00
# 75%   1,374.25  62.00
# max   1,499.00  75.00

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Возможно, ты бы тоже хотел избавиться от экспонентациальных форм и лишних запятушек при использовании метода `describe`, тогда проиши в начале настройку `pandas`:
#
# ```python
# pd.set_option('display.float_format', '{:,.2f}'.format)
# ```
# </div>

# %% [markdown]
# <div style="border:solid light blue 1px; padding: 1px">
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
#  Ок, принято. Полезная штука - Спасибо!
#
#
# </div>

# %% [markdown]
# Методом display() показываем столбец __churn_date__ и методом isnull() выводим пропущенные значения  по исследуемому users

# %%
display(users[users['churn_date'].isnull()])# выводим пропущенные значения по столбцу churn_date
# Out:
#      user_id  age churn_date         city first_name  last_name    reg_date  \
# 0       1000   52        NaN    Краснодар     Рафаил  Верещагин  2018-05-25
# 1       1001   41        NaN       Москва       Иван       Ежов  2018-11-01
# 2       1002   59        NaN  Стерлитамак    Евгений  Абрамович  2018-06-17
# 3       1003   23        NaN       Москва      Белла   Белякова  2018-08-17
# 4       1004   68        NaN  Новокузнецк    Татьяна   Авдеенко  2018-05-14
# ..       ...  ...        ...          ...        ...        ...         ...
# 494     1494   62        NaN         Омск      Ренат   Андропов  2018-08-17
# 495     1495   65        NaN      Иркутск  Авксентий      Фокин  2018-08-28
# 496     1496   36        NaN      Вологда     Трифон     Блохин  2018-01-27
# 497     1497   32        NaN    Челябинск   Каролина     Агеева  2018-10-09
# 499     1499   35        NaN        Пермь     Гектор   Корнилов  2018-09-27
#
#     tariff
# 0    ultra
# 1    smart
# 2    smart
# ...

# %%
users.isnull().sum()# выводим пропущенные значения по столбцу churn_date
# Out:
# user_id         0
# age             0
# churn_date    462
# city            0
# first_name      0
# last_name       0
# reg_date        0
# tariff          0
# dtype: int64

# %%
# смотрим пропуски и их процентное  соотношение к общему количеству по таблице users
report = users.isna().sum().to_frame()
report = report.rename(columns = {0: 'missing_values'})
report['% of total'] = (report['missing_values'] / users.shape[0]).round(2)
report.sort_values(by = 'missing_values', ascending = False)
# Out:
#             missing_values  % of total
# churn_date             462        0.92
# user_id                  0        0.00
# age                      0        0.00
# city                     0        0.00
# first_name               0        0.00
# last_name                0        0.00
# reg_date                 0        0.00
# tariff                   0        0.00

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Чтобы посмотреть процентное соотношение, можно воспользоваться одной строчкой:
#
# ```python
# 100*(users.isna().sum()/len(users))
# ```
# Это немного оптимальней, но твой подход очень изящный.
# </div>

# %%
100*(users.isna().sum()/len(users)) # добавил после комментария ревьювера
# Out:
# user_id       0.00
# age           0.00
# churn_date   92.40
# city          0.00
# first_name    0.00
# last_name     0.00
# reg_date      0.00
# tariff        0.00
# dtype: float64

# %%
100*users.isna().mean() #Комментарий ревьюера V2:Еще вспомнил, что вот так короче 100*users.isna().mean()
# Out:
# user_id       0.00
# age           0.00
# churn_date   92.40
# city          0.00
# first_name    0.00
# last_name     0.00
# reg_date      0.00
# tariff        0.00
# dtype: float64

# %% [markdown]
# <div style="border:solid light blue 1px; padding: 1px">
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
#   Спасибо. Принято.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера V2:</b>
#
# Еще вспомнил, что вот так короче `100*users.isna().mean()`.
# </div>

# %% [markdown]
# __Вывод__ <br>По  Таблице __users__ сделали след первоначальные выводы:<br> Имеем 2столбца с количественными и 6 с категориальными данными.
# - Столбец __churn_date__ имеет 462 пропущенных значения(нет значения, так как клиент действующий), оставим как есть.
# - Столбецы __churn_date__ и __reg_date__ необходимо изменить формат на ___datetime___, выполним на этапе - замена типа данных.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# С выводами согласен. Огромный плюс тебе за оформление. Не представляешь как же приятно проверять работу, когда есть четкие заголовки, выделенные места, на которые стоит обратить внимание. Молодец!
# </div>

# %% [markdown]
# ---

# %% [markdown]
# `2.Таблица` ____calls____ — (информация о звонках):<br>
# - **id** — уникальный номер звонка
# - **call_date** — дата звонка
# - **duration** — длительность звонка в минутах
# - **user_id** — идентификатор пользователя, сделавшего звонок<br>

# %%
calls#перевый взгляд на  calls
# Out:
#               id   call_date  duration  user_id
# 0         1000_0  2018-07-25      0.00     1000
# 1         1000_1  2018-08-17      0.00     1000
# 2         1000_2  2018-06-11      2.85     1000
# 3         1000_3  2018-09-21     13.80     1000
# 4         1000_4  2018-12-15      5.18     1000
# ...          ...         ...       ...      ...
# 202602  1499_215  2018-12-26      0.76     1499
# 202603  1499_216  2018-10-18     18.83     1499
# 202604  1499_217  2018-11-10     10.81     1499
# 202605  1499_218  2018-10-06      4.27     1499
# 202606  1499_219  2018-12-14     19.62     1499
#
# [202607 rows x 4 columns]

# %%
calls.info()#смотрим в каком формате представлены столбцы из calls
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         202607 non-null  object
#  1   call_date  202607 non-null  object
#  2   duration   202607 non-null  float64
#  3   user_id    202607 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.2+ MB

# %%
calls.describe()# цифровая оценка данных из calls
# Out:
#         duration    user_id
# count 202,607.00 202,607.00
# mean        6.76   1,253.94
# std         5.84     144.72
# min         0.00   1,000.00
# 25%         1.30   1,126.00
# 50%         6.00   1,260.00
# 75%        10.70   1,379.00
# max        38.00   1,499.00

# %%
# смотрим пропуски и их процентное  соотношение к общему количеству по таблице calls
report = calls.isna().sum().to_frame()
report = report.rename(columns = {0: 'missing_values'})
report['% of total'] = (report['missing_values'] / calls.shape[0]).round(2)
report.sort_values(by = 'missing_values', ascending = False)
# Out:
#            missing_values  % of total
# id                      0        0.00
# call_date               0        0.00
# duration                0        0.00
# user_id                 0        0.00

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Если ты хочешь писать такую структуру про проверке пропусков для каждого датасета, тогда бы оптимальней создать функцию, которая тебе будет выдавать результат, а принимать датасет. Отдельно прописывать каждый раз одни и те же строки кода не очень.
# </div>

# %% [markdown]
# <div style="border:solid light blue 1px; padding: 1px">
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Хорошая идея, в будушем создам функцию для этих проверок. Спасибо.
#
# </div>

# %% [markdown]
# __Вывод__ <br>По  Таблице __calls__ сделали след первоначальные выводы:
# - В столбце __call_date__ необходимо сменть формать на ___datetime___
# - В столбце __duration__ мин значение разговора 0.0 минут на этапе предобработки проанализирум, преобразуем либо удалим.
# - В столбце __duration__ данные округлим вверх, до целого числа (правила компании "Мегалайн") -  переведем в формат int.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# С выводами по этому датасету согласен.
# </div>

# %% [markdown]
# ---

# %% [markdown]
# `3.Таблица` ___messages___ — (информация о сообщениях):<br>
# - **id** — уникальный номер сообщения
# - **message_date** — дата сообщения
# - **user_id** — идентификатор пользователя, отправившего сообщение<br>

# %%
messages#перевый взгляд на  messages
# Out:
#               id message_date  user_id
# 0         1000_0   2018-06-27     1000
# 1         1000_1   2018-10-08     1000
# 2         1000_2   2018-08-04     1000
# 3         1000_3   2018-06-16     1000
# 4         1000_4   2018-12-05     1000
# ...          ...          ...      ...
# 123031  1499_179   2018-12-12     1499
# 123032  1499_180   2018-09-28     1499
# 123033  1499_181   2018-09-27     1499
# 123034  1499_182   2018-11-15     1499
# 123035  1499_183   2018-11-16     1499
#
# [123036 rows x 3 columns]

# %%
messages.info()#смотрим в каком формате представлены столбцы из df_messages
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123036 entries, 0 to 123035
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            123036 non-null  object
#  1   message_date  123036 non-null  object
#  2   user_id       123036 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 2.8+ MB

# %%
messages.describe()# цифровая оценка данных из df_messages
# Out:
#          user_id
# count 123,036.00
# mean    1,256.99
# std       143.52
# min     1,000.00
# 25%     1,134.00
# 50%     1,271.00
# 75%     1,381.00
# max     1,499.00

# %%
report = messages.isna().sum().to_frame()
report = report.rename(columns = {0: 'missing_values'})
report['% of total'] = (report['missing_values'] / messages.shape[0]).round(2)
report.sort_values(by = 'missing_values', ascending = False)
# Out:
#               missing_values  % of total
# id                         0        0.00
# message_date               0        0.00
# user_id                    0        0.00

# %% [markdown]
# __Вывод__ <br>По  Таблице __messages__ сделали след первоначальные выводы:<br>
# - В столбце __message_date__ необходимо сменть формать на ___datetime___

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Тут все понятно. Преобразований не требуется.
# </div>

# %% [markdown]
# ---

# %% [markdown]
# `4.Таблица` ___internet___ — (информация об интернет-сессиях):<br>
# - **id** — уникальный номер сессии
# - **mb_used** — объём потраченного за сессию интернет-трафика (в мегабайтах)
# - **session_date** — дата интернет-сессии
# - **user_id** — идентификатор пользователя<br>

# %%
internet#перевый взгляд нa таблицу internet
# Out:
#         Unnamed: 0        id  mb_used session_date  user_id
# 0                0    1000_0   112.95   2018-11-25     1000
# 1                1    1000_1 1,052.81   2018-09-07     1000
# 2                2    1000_2 1,197.26   2018-06-25     1000
# 3                3    1000_3   550.27   2018-08-22     1000
# 4                4    1000_4   302.56   2018-09-24     1000
# ...            ...       ...      ...          ...      ...
# 149391      149391  1499_152   318.90   2018-10-03     1499
# 149392      149392  1499_153   490.13   2018-12-14     1499
# 149393      149393  1499_154     0.00   2018-10-27     1499
# 149394      149394  1499_155 1,246.32   2018-11-26     1499
# 149395      149395  1499_156   544.37   2018-10-26     1499
#
# [149396 rows x 5 columns]

# %%
internet.info()#смотрим в каком формате представлены столбцы из internet
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149396 entries, 0 to 149395
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    149396 non-null  int64
#  1   id            149396 non-null  object
#  2   mb_used       149396 non-null  float64
#  3   session_date  149396 non-null  object
#  4   user_id       149396 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 5.7+ MB

# %%
internet.describe()# цифровая оценка данных из internet
# Out:
#        Unnamed: 0    mb_used    user_id
# count  149,396.00 149,396.00 149,396.00
# mean    74,697.50     370.19   1,252.10
# std     43,127.05     278.30     144.05
# min          0.00       0.00   1,000.00
# 25%     37,348.75     138.19   1,130.00
# 50%     74,697.50     348.01   1,251.00
# 75%    112,046.25     559.55   1,380.00
# max    149,395.00   1,724.83   1,499.00

# %%
report = internet.isna().sum().to_frame()
report = report.rename(columns = {0: 'missing_values'})
report['% of total'] = (report['missing_values'] / internet.shape[0]).round(2)
report.sort_values(by = 'missing_values', ascending = False)
# Out:
#               missing_values  % of total
# Unnamed: 0                 0        0.00
# id                         0        0.00
# mb_used                    0        0.00
# session_date               0        0.00
# user_id                    0        0.00

# %% [markdown]
# __Вывод__ <br>По  Таблице __internet__ сделали след первоначальные выводы:<br>
# - В столбце __session_date__ необходимо сменть формать на ___datetime___
# - Проанализировать столбец __Unnamed: 0__ в описании нет, назначение не понятно. При необходимости удалить.
# - В столбце __mb_used__ есть значение __0__, надо оценить как оно повлияет на дальнейший анализ и  выводы.
# - В столбце __mb_used__ данные округлим вверх, до целого числа (правила компании "Мегалайн") -  переведем в формат int.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Здесь аналогично звонкам - все корректно.
# </div>

# %% [markdown]
# ---

# %% [markdown]
# `5.Таблица` ___tariffs___ — (информация о тарифах):
# - **tariff_name** — название тарифа
# - **rub_monthly_fee** — ежемесячная абонентская плата в рублях
# - **minutes_included** — количество минут разговора в месяц, включённых в абонентскую плату
# - **messages_included** — количество сообщений в месяц, включённых в абонентскую плату
# - **mb_per_month_included** — объём интернет-трафика, включённого в абонентскую плату (в мегабайтах)
# - **rub_per_minute** — стоимость минуты разговора сверх тарифного пакета (например, если в тарифе 100 минут разговора в месяц, то со 101 минуты будет взиматься плата)
# - **rub_per_message** — стоимость отправки сообщения сверх тарифного пакета
# - **rub_per_gb** — стоимость дополнительного гигабайта интернет-трафика сверх тарифного пакета (1 гигабайт = 1024 мегабайта)

# %%
tariffs#перевый взгляд нa таблицу tariff
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute tariff_name
# 0              550         200                3               3       smart
# 1             1950         150                1               1       ultra

# %%
tariffs.info()#смотрим в каком формате представлены столбцы из tariffs
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   messages_included      2 non-null      int64
#  1   mb_per_month_included  2 non-null      int64
#  2   minutes_included       2 non-null      int64
#  3   rub_monthly_fee        2 non-null      int64
#  4   rub_per_gb             2 non-null      int64
#  5   rub_per_message        2 non-null      int64
#  6   rub_per_minute         2 non-null      int64
#  7   tariff_name            2 non-null      object
# dtypes: int64(7), object(1)
# memory usage: 256.0+ bytes

# %%
report = tariffs.isna().sum().to_frame()
report = report.rename(columns = {0: 'missing_values'})
report['% of total'] = (report['missing_values'] / tariffs.shape[0]).round(2)
report.sort_values(by = 'missing_values', ascending = False)
# Out:
#                        missing_values  % of total
# messages_included                   0        0.00
# mb_per_month_included               0        0.00
# minutes_included                    0        0.00
# rub_monthly_fee                     0        0.00
# rub_per_gb                          0        0.00
# rub_per_message                     0        0.00
# rub_per_minute                      0        0.00
# tariff_name                         0        0.00

# %% [markdown]
# __Вывод__ <br>По  Таблице __tariffs__ сделали след первоначальные выводы:
# - По данной таблице замечаний  пока нет.<br>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Да, в тарифах нужно просто будет воспользоваться нужными значениями для расчетов.
# </div>

# %% [markdown]
# ---

# %% [markdown]
# ### Вывод
# [&#10224;](#step1)

# %% [markdown]
#  <div style="border:solid green 2px; padding: 20px">
#
# Имеем 5 таблиц, 4-е из которых имеют общий столбец __user_id__ дающий возможность их объединения в дальнейшем
# - В таблице __users__ в столбце  __churn_date__ имеет 462 пропущенных значения(нет значения, так как клиент действующий), оставлям без изменений
# - Столбецы __churn_date__ и __reg_date__ необходимо изменить формат на ___datetime___.
# - В столбце __call_date__ необходимо сменть формать на ___datetime___
# - В столбце __duration__ обнаружено  мин значение разговора 0.0 минут округлим до целых
# - В столбце __message_date__ необходимо сменть формать на ___datetime___
# - В столбце __session_date__ необходимо сменть формать на ___datetime___
# - Проанализировать столбец __Unnamed: 0__ в описании нет, назначение не понятно. При необходимости удалить.
# - В столбце __mb_used__ есть значение __0__, надо оценить как оно повлияет на дальнейший анализ и  выводы.
# - В столбце __mb_used__ данные округлим вверх, до целого числа (правила компании "Мегалайн") -  переведем в формат int.
# - В столбце __duration__ данные округлим вверх, до целого числа (правила компании "Мегалайн") -  переведем в формат int.
#
# Информация из таблицы __tariffs__ будет использована для получения из неё данных о тарифах, и подставления их к соответствующим тарифным планам __"smart"__  либо __"ultra"__.
#
#
# Поэтапно, по каждой таблице изучили описание столбцов  сравнив  их с информацией полученной при помощи метода info и describe   -  определили возможные проблемы в данных нуждающиеся в предобработке.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Первый взгляд на данные образцово-показательный. План очень подробный и понятный, со всем шагами я согласен. Оформление на высоком уровне, мне как ревьюеру, очень удобно проверять.
# </div>

# %% [markdown]
# ## Предобработка данных
# [&#10224;](#step1)

# %% [markdown]
#  <div style="border:solid green 2px; padding: 20px">
#
# - Обработаем обнаруженные проблемы в таблицах -  пропущенные значения, значение 0 в показаниях минут и мегабайт, сомнительный столбец Unnamed:
# - Для удобства дальнейшего использования, объеденим обработанные от пропусков и не нужных значений, таблицы в одну. Во вновь образованную таблицу добавим значения тарифных планов.
# - Произведем замену установленных в столбцах форматов __object__ на  __datetime__ а также __float__ на __int__
# - проверим на наличие дубликатов в данных.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Отлично, что стараешься расписывать свой план действий!
# </div>

# %% [markdown]
# ###  Обработка пропусков
# [&#10224;](#step1)

# %% [markdown]
# Предварительно проверим таблицы  на  наличие дубликатов

# %%
for i in df_list:
    print('Количество обнаруженных дубликатов:')
    display(i.duplicated().sum())# функцией .duplicated() определяем дубликаты, функцией .sum() суммируем их (получаем общее количество)
# Out:
# Количество обнаруженных дубликатов:
# 0
# Количество обнаруженных дубликатов:
# 0
# Количество обнаруженных дубликатов:
# 0
# Количество обнаруженных дубликатов:
# 0
# Количество обнаруженных дубликатов:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# По факту для проверки дубликатов можно было бы проверить уникальность ключей в датасетах, если у них нету дубликатов, то отвечает на поставленный вопрос. Так же общая проверка, которую ты привел с помощью метода `duplicated().sum()` вполне корректна - она так же подтверждает уникальность ключей.
# </div>

# %% [markdown]
# ---

# %% [markdown]
# Посмотрим пропуски

# %% [markdown]
# Таблице __users__ обнаружили следующие моменты нуждающиеся в обработке:
# - Столбец __churn_date__ имеет 462 пропущенных значения(нет значения, так как клиент действующий), решено оставить без изменений.

# %%
display(users[users['churn_date'].isnull()])# выводим пропущенные значения по столбцу churn_date
# Out:
#      user_id  age churn_date         city first_name  last_name    reg_date  \
# 0       1000   52        NaN    Краснодар     Рафаил  Верещагин  2018-05-25
# 1       1001   41        NaN       Москва       Иван       Ежов  2018-11-01
# 2       1002   59        NaN  Стерлитамак    Евгений  Абрамович  2018-06-17
# 3       1003   23        NaN       Москва      Белла   Белякова  2018-08-17
# 4       1004   68        NaN  Новокузнецк    Татьяна   Авдеенко  2018-05-14
# ..       ...  ...        ...          ...        ...        ...         ...
# 494     1494   62        NaN         Омск      Ренат   Андропов  2018-08-17
# 495     1495   65        NaN      Иркутск  Авксентий      Фокин  2018-08-28
# 496     1496   36        NaN      Вологда     Трифон     Блохин  2018-01-27
# 497     1497   32        NaN    Челябинск   Каролина     Агеева  2018-10-09
# 499     1499   35        NaN        Пермь     Гектор   Корнилов  2018-09-27
#
#     tariff
# 0    ultra
# 1    smart
# 2    smart
# ...

# %%
users.isnull().sum()# выводим пропущенные значения по столбцу churn_date
# Out:
# user_id         0
# age             0
# churn_date    462
# city            0
# first_name      0
# last_name       0
# reg_date        0
# tariff          0
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# По  Таблице __calls__ обнаружили следующие моменты нуждающиеся в обработке:
#
# - В столбце __duration__ мин значение разговора 0.0 минут.  Удалим значениек 0 минут разговора из столбца duration. Возможно это сбои сети недозвоны. Этот показатель не тарифицируется, в дальнейших расчетах может сильно исказить выводы.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# С рассуждением согласен, 0 длительность не учитывается в расчетах, по сути эти данные нам не нужны.
# </div>

# %%
calls['duration'].value_counts()# смотрим сколько упоминаний со значение 0 минут.
# Out:
# 0.00     39613
# 4.49       142
# 5.50       142
# 6.15       141
# 6.38       141
#          ...
# 27.02        1
# 26.19        1
# 25.34        1
# 27.13        1
# 24.28        1
# Name: duration, Length: 2871, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Здесь можно было бы сразу посчитать долевое соотношение, чтобы понять сразу много их или мало:
#
# ```python
# calls['duration'].value_counts(normalize=True).loc[0]
# ```
# </div>

# %%
calls['duration'].hist(bins=60,figsize=(12, 7)).set_title('Гистограмма продолжительности разговора')
plt.xlim(0,35)
plt.xlabel("время разговора")
plt.ylabel("количество звонков")
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Гистограмма здесь очень полезна, она так же наглядно отражает существенное кол-во нулевых звонков. Все подписи присутствуют, масштаб подобран корректно - супер. Только можно увеличить размер подписей, больно уж мелкие.
# </div>

# %%
calls.describe()
# Out:
#         duration    user_id
# count 202,607.00 202,607.00
# mean        6.76   1,253.94
# std         5.84     144.72
# min         0.00   1,000.00
# 25%         1.30   1,126.00
# 50%         6.00   1,260.00
# 75%        10.70   1,379.00
# max        38.00   1,499.00

# %% [markdown]
# Имеем  39613 строк со значением 0 минут продолжительность разговора. Уберем  данные значения из таблицы.

# %%
calls = calls.loc[calls['duration'] != 0.00]# убираем из 'duration' все значения равные 0
# еще  способ удаления  calls = calls.query('duration != 0.00')

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Да, оба способа корректны.
# </div>

# %%
calls.describe()
# Out:
#         duration    user_id
# count 162,994.00 162,994.00
# mean        8.40   1,254.15
# std         5.35     144.75
# min         0.01   1,000.00
# 25%         4.17   1,126.00
# 50%         7.74   1,261.00
# 75%        11.85   1,379.00
# max        38.00   1,499.00

# %%
calls['duration'].hist(bins=60,figsize=(12, 7)).set_title('Гистаграмма продолжительности разговора')
plt.xlim(0,35)

plt.xlabel("время разговора")
plt.ylabel("количество звонков")
plt.show()

# %% [markdown]
# Проверим результат замены

# %%
calls['duration'].value_counts()# смотрим сколько упоминаний со значение 0 минут.
# Out:
# 4.49     142
# 5.50     142
# 6.38     141
# 6.15     141
# 4.92     139
#         ...
# 25.67      1
# 27.19      1
# 28.87      1
# 26.07      1
# 27.63      1
# Name: duration, Length: 2870, dtype: int64

# %%
calls.info()# проверим формат
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162994 entries, 2 to 202606
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         162994 non-null  object
#  1   call_date  162994 non-null  object
#  2   duration   162994 non-null  float64
#  3   user_id    162994 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.2+ MB

# %% [markdown]
# ---

# %% [markdown]
# В Таблице __internet__ обнаружили следующие моменты нуждающиеся в обработке:
#
# - Проанализировать столбец __Unnamed: 0__ в описании нет, назначение не понятно. При необходимости удалить.
# - В столбце __mb_used__ есть значение __0__, надо оценить как оно повлияет на дальнейший анализ и  выводы.

# %%
internet['Unnamed: 0']
# Out:
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#            ...
# 149391    149391
# 149392    149392
# 149393    149393
# 149394    149394
# 149395    149395
# Name: Unnamed: 0, Length: 149396, dtype: int64

# %%
internet.describe()
# Out:
#        Unnamed: 0    mb_used    user_id
# count  149,396.00 149,396.00 149,396.00
# mean    74,697.50     370.19   1,252.10
# std     43,127.05     278.30     144.05
# min          0.00       0.00   1,000.00
# 25%     37,348.75     138.19   1,130.00
# 50%     74,697.50     348.01   1,251.00
# 75%    112,046.25     559.55   1,380.00
# max    149,395.00   1,724.83   1,499.00

# %%
internet
# Out:
#         Unnamed: 0        id  mb_used session_date  user_id
# 0                0    1000_0   112.95   2018-11-25     1000
# 1                1    1000_1 1,052.81   2018-09-07     1000
# 2                2    1000_2 1,197.26   2018-06-25     1000
# 3                3    1000_3   550.27   2018-08-22     1000
# 4                4    1000_4   302.56   2018-09-24     1000
# ...            ...       ...      ...          ...      ...
# 149391      149391  1499_152   318.90   2018-10-03     1499
# 149392      149392  1499_153   490.13   2018-12-14     1499
# 149393      149393  1499_154     0.00   2018-10-27     1499
# 149394      149394  1499_155 1,246.32   2018-11-26     1499
# 149395      149395  1499_156   544.37   2018-10-26     1499
#
# [149396 rows x 5 columns]

# %%
internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149396 entries, 0 to 149395
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    149396 non-null  int64
#  1   id            149396 non-null  object
#  2   mb_used       149396 non-null  float64
#  3   session_date  149396 non-null  object
#  4   user_id       149396 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 5.7+ MB

# %% [markdown]
# Предназначение столбца __Unnamed: 0__ установить не удалось, произведем его удалени из таблицы __internet__

# %%
internet = internet.drop(['Unnamed: 0'], axis = 1)
# методом drop удаляем в таблице internet столбец Unnamed: 0 сохраняем полученную таблицу без Unnamed: 0 в internet

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Да, он не нужен, действие корректно.
# </div>

# %%
internet# смотрим полученный результат
# Out:
#               id  mb_used session_date  user_id
# 0         1000_0   112.95   2018-11-25     1000
# 1         1000_1 1,052.81   2018-09-07     1000
# 2         1000_2 1,197.26   2018-06-25     1000
# 3         1000_3   550.27   2018-08-22     1000
# 4         1000_4   302.56   2018-09-24     1000
# ...          ...      ...          ...      ...
# 149391  1499_152   318.90   2018-10-03     1499
# 149392  1499_153   490.13   2018-12-14     1499
# 149393  1499_154     0.00   2018-10-27     1499
# 149394  1499_155 1,246.32   2018-11-26     1499
# 149395  1499_156   544.37   2018-10-26     1499
#
# [149396 rows x 4 columns]

# %% [markdown]
# ---

# %% [markdown]
# - В столбце __mb_used__ есть значение __0__, надо оценить как оно повлияет на дальнейший анализ и  выводы.

# %%
internet['mb_used'].value_counts()
# Out:
# 0.00      19598
# 197.56        9
# 447.30        9
# 335.91        9
# 108.95        8
#           ...
# 72.49         1
# 846.22        1
# 429.17        1
# 899.03        1
# 483.87        1
# Name: mb_used, Length: 70003, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Здесь, аналогично звонкам, лучше сразу смотреть долевое соотношение, т.к. кол-во по сути ни о чем не говорит.
# </div>

# %%
internet['mb_used'].value_counts(normalize=True).loc[0]# добавил после комментария ревьювера
# Out:
# 0.13118155773916304

# %% [markdown]
# Похожая ситуации с 0 минут разговора, было зафиксировано __19598__ случаев когда количество  использованных  мегабай равнялось 0
# эта информация 0 значение не понадобиться для дальнейшего анализа, возможно это сбои, обрывы и последующие неудачные подключения Удалим значение 0 из столбца mb_used. Помним что необходимо изменить формат на целочисленное значение приведем к типу  int

# %%
internet['mb_used'].hist(bins=60,figsize=(12, 7)).set_title('Гистограмма  интернет сессии')
plt.xlim(0,1500)
plt.xlabel("время сессии")
plt.ylabel("количество сессий")
plt.show()

# %%
internet['mb_used'].describe()
# Out:
# count   149,396.00
# mean        370.19
# std         278.30
# min           0.00
# 25%         138.19
# 50%         348.01
# 75%         559.55
# max       1,724.83
# Name: mb_used, dtype: float64

# %%
internet = internet.loc[internet['mb_used'] >= 0.1]# убираем из 'mb_used' все значения меньше 0.1`
#df_internet = df_internet.query('mb_used >= 0.1')

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Действие корректно.
# </div>

# %%
internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129788 entries, 0 to 149395
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            129788 non-null  object
#  1   mb_used       129788 non-null  float64
#  2   session_date  129788 non-null  object
#  3   user_id       129788 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 5.0+ MB

# %% [markdown]
# Проверяем произошла ли замена значения 0 на ближайшее большее значение.

# %%
internet.describe()
# Out:
#          mb_used    user_id
# count 129,788.00 129,788.00
# mean      426.12   1,253.05
# std       255.58     143.78
# min         0.10   1,000.00
# 25%       227.51   1,132.00
# 50%       400.57   1,252.00
# 75%       592.97   1,380.00
# max     1,724.83   1,499.00

# %%
internet['mb_used'].hist(bins=60,figsize=(12, 7)).set_title('Гистограмма интернет сессии')
plt.xlim(0,1500)
plt.xlabel("время сессии")
plt.ylabel("количество сессий")
plt.show()

# %% [markdown]
#  **Вывод**

# %% [markdown]
#  <div style="border:solid green 2px; padding: 20px">
#
# Данные частично предобработаны. Убрали значения 0 ноль из телефонных звонко и интернет сессий. Удалилил столбец без предназначения.  Для удобства обработки и анализа  объединим имеющиеся  таблицы по столбуц user_id'  в одну.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# С выводами согласен, действия корректны.
# </div>

# %% [markdown]
# ### Замена типа данных
# [&#10224;](#step1)

# %% [markdown]
# Необходимо сменить форматы в следующих столбцах:
#
# - В таблице **users**  изменим форматы в столбецах __churn_date__ и __reg_date__ необходимо изменить формат на ___datetime___
# - В таблице __calls__ изменим форматы в столбеце __call_date__  необходимо изменить формат на ___datetime___
# - В таблиах __messages, internet,__ изменим форматы в столбецах __message_date, session_date__   на ___datetime___
# - Добавим к каждой таблице  __calls__ __messages__ __internet__  -  столбец __month__ месяц.
# - Также необходимо изменить формат float на  int с строках  __duration__   и __mb_used__

# %% [markdown]
# Посмотрим на текущее состояние форматов в таблицах.

# %%
df_list = [users, calls , messages, internet,  tariffs]
for i in df_list:
    display(i.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   age         500 non-null    int64
#  2   churn_date  38 non-null     object
#  3   city        500 non-null    object
#  4   first_name  500 non-null    object
#  5   last_name   500 non-null    object
#  6   reg_date    500 non-null    object
#  7   tariff      500 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162994 entries, 2 to 202606
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         162994 non-null  object
#  1   call_date  162994 non-null  object
#  2   duration   162994 non-null  float64
#  3   user_id    162994 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Хорошо, что оптимизировал вывод с помощью цикла. Могу рекомендовать добавить еще названия дф перед самим описанием, чтобы было наглядно видно к какому дф они относятся.
# </div>

# %% [markdown]
# #### Изменим форматы object на  datetime в столбцах churn_date, reg_date, call_date, message_date, session_date<a class="tocSkip">

# %% [markdown]
# Замена формата object на   datetime64 в столбце churn_date

# %%
users['churn_date'] = pd.to_datetime(users['churn_date'], format='%Y-%m-%d')
# переводим даты к корректному формату     format='%Y-%m-%d' цифровое обозначение 
#'%Y-%m-%dT%H:%M:%S' буквенное обозначение месяца

# %%
users
# Out:
#      user_id  age churn_date         city first_name  last_name    reg_date  \
# 0       1000   52        NaT    Краснодар     Рафаил  Верещагин  2018-05-25
# 1       1001   41        NaT       Москва       Иван       Ежов  2018-11-01
# 2       1002   59        NaT  Стерлитамак    Евгений  Абрамович  2018-06-17
# 3       1003   23        NaT       Москва      Белла   Белякова  2018-08-17
# 4       1004   68        NaT  Новокузнецк    Татьяна   Авдеенко  2018-05-14
# ..       ...  ...        ...          ...        ...        ...         ...
# 495     1495   65        NaT      Иркутск  Авксентий      Фокин  2018-08-28
# 496     1496   36        NaT      Вологда     Трифон     Блохин  2018-01-27
# 497     1497   32        NaT    Челябинск   Каролина     Агеева  2018-10-09
# 498     1498   68 2018-10-25  Владикавказ   Всеволод    Акимчин  2018-07-19
# 499     1499   35        NaT        Пермь     Гектор   Корнилов  2018-09-27
#
#     tariff
# 0    ultra
# 1    smart
# 2    smart
# ...

# %% [markdown]
# Замена формата object на   datetime64 в столбце reg_date

# %%
users['reg_date'] = pd.to_datetime(users['reg_date'], format='%Y-%m-%d')
# переводим даты к корректному формату

# %% [markdown]
# Замена формата object на   datetime64 в столбце call_date

# %%
calls['call_date'] = pd.to_datetime(calls['call_date'], format='%Y-%m-%d')
# переводим даты к корректному формату
# Out:
# <ipython-input-56-b294d1166c96>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calls['call_date'] = pd.to_datetime(calls['call_date'], format='%Y-%m-%d')

# %% [markdown]
# Замена формата object на   datetime64 в столбце message_date

# %%
messages['message_date'] = pd.to_datetime(messages['message_date'], format='%Y-%m-%d')
# переводим даты к корректному формату

# %% [markdown]
# Замена формата object на   datetime64 в столбце session_date

# %%
internet['session_date'] = pd.to_datetime(internet['session_date'], format='%Y-%m-%d')
# переводим даты к корректному виду
# Out:
# <ipython-input-58-d40646305c29>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   internet['session_date'] = pd.to_datetime(internet['session_date'], format='%Y-%m-%d')

# %%
df_list = [users, calls , messages, internet] # проверим изменения
for i in df_list:
    display(i.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   age         500 non-null    int64
#  2   churn_date  38 non-null     datetime64[ns]
#  3   city        500 non-null    object
#  4   first_name  500 non-null    object
#  5   last_name   500 non-null    object
#  6   reg_date    500 non-null    datetime64[ns]
#  7   tariff      500 non-null    object
# dtypes: datetime64[ns](2), int64(2), object(4)
# memory usage: 31.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162994 entries, 2 to 202606
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         162994 non-null  object
#  1   call_date  162994 non-null  datetime64[ns]
#  2   duration   162994 non-null  float64
#  3   user_id    162994 non-null  int64
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# С заменой типов данных на временные - согласен.
# </div>

# %%
calls.head()
# Out:
#        id  call_date  duration  user_id
# 2  1000_2 2018-06-11      2.85     1000
# 3  1000_3 2018-09-21     13.80     1000
# 4  1000_4 2018-12-15      5.18     1000
# 7  1000_7 2018-08-22     18.31     1000
# 8  1000_8 2018-09-15     18.44     1000

# %%
internet.head(15)
# Out:
#          id  mb_used session_date  user_id
# 0    1000_0   112.95   2018-11-25     1000
# 1    1000_1 1,052.81   2018-09-07     1000
# 2    1000_2 1,197.26   2018-06-25     1000
# 3    1000_3   550.27   2018-08-22     1000
# 4    1000_4   302.56   2018-09-24     1000
# 5    1000_5   399.97   2018-10-02     1000
# 6    1000_6   540.08   2018-09-07     1000
# 7    1000_7   415.70   2018-07-11     1000
# 8    1000_8   505.40   2018-10-08     1000
# 9    1000_9   345.54   2018-09-03     1000
# 10  1000_10   385.14   2018-09-27     1000
# 12  1000_12   375.87   2018-06-20     1000
# 13  1000_13   393.83   2018-08-09     1000
# 14  1000_14   180.64   2018-08-11     1000
# 15  1000_15   337.71   2018-07-21     1000

# %% [markdown]
# В столбцах __duration и mb_used__ обнаружен формат float64 (вещественные числа), применяя метод .astype(), заменим его на формат int(целочисленные). Это необходимо для округления минут и мегабайт до целого числа, по условиям компании "Мегалайн"

# %%
#заменим формат данных в столбцах duration и mb_used , 
# с вещественного float64 на целочисленное  int64 
calls['duration'] = calls['duration'].apply(np.ceil).astype('int64')# методом.apply(np.ceil) округлили в большую сторону 
#методом .astype() для столбца duration устан формат int64 
internet['mb_used'] = internet['mb_used'].apply(np.ceil).astype('int64')# методом.apply(np.ceil) округлили в большую сторону 
#методом .astype() для столбца mb_used устан формат int64
# Out:
# <ipython-input-62-90937788c1bc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calls['duration'] = calls['duration'].apply(np.ceil).astype('int64')# методом.apply(np.ceil) округлили в большую сторону
# <ipython-input-62-90937788c1bc>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   internet['mb_used'] = internet['mb_used'].apply(np.ceil).astype('int64')# методом.apply(np.ceil) округлили в большую сторону

# %% [markdown]
# <div style="border:solid light blue 1px; padding: 1px">
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Выше код исправлен после замечания ревьювера.
#
# </div>

# %% [raw]
# Ошибочное решение!!!
#
# calls['duration'] = (calls['duration'] + 1).astype('int64')# методом .astype() для столбца duration устан формат int64
# # int округляет до целого значения, т.е пример(уменьшает значение 2.85 до 2) это по условию задачи не приемлемо, прибавим 1
# # тогда округлится до большего значения. Но 2.85 это 3мин 25 секунд. в условиях ничего не сказано, и почему не указывают 3.25
# # в место 2.85
#
# internet['mb_used'] = (internet['mb_used'] + 1).astype('int64')# методом .astype() для столбца mb_used устан формат int64

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера:</b>
#
# 1. Смотри, на самом деле ты нашел интересную тему для обсуждения, а именно, что 2.85 минуты - это 3 минуты 25 секунд, но это не совсем так. У тебя указано, что `duration` - это длительность звонка в минутах, а значит, 2.85 минуты - это 2.85*60=171 секунда и целых 3 минут тут нет, а будет 2 минуты и 51 секунда.
#
# 2. Теперь, давай попробуем разобраться с округлением. Когда ты прибавляешь единицу к длительности звонка, то у тебя корректно учитываются и округляются при приведении к `int` только те значения, которые были дробными, а как же целые? Если длительность звонка была 1 минута, то ты прибавил минуту и получилось 2 минуты и это значение останется, а должна остаться 1 минута. Подумай, как можно корректно изменить свой подход и получить нужные значения после округления.
#
# 3. Аналогично, 2-ому пункту округли корректно и трафик, т.к. этот метод здесь так же не подходит.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера V2:</b>
#
# Да, супер, `ceil` как раз выполняет отлично поставленную задачу.
# </div>

# %% [markdown]
# Проверяем смену форматов в таблицах calls  и internet

# %%
calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162994 entries, 2 to 202606
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         162994 non-null  object
#  1   call_date  162994 non-null  datetime64[ns]
#  2   duration   162994 non-null  int64
#  3   user_id    162994 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 6.2+ MB

# %%
calls.head(15)
# Out:
#          id  call_date  duration  user_id
# 2    1000_2 2018-06-11         3     1000
# 3    1000_3 2018-09-21        14     1000
# 4    1000_4 2018-12-15         6     1000
# 7    1000_7 2018-08-22        19     1000
# 8    1000_8 2018-09-15        19     1000
# 10  1000_10 2018-08-22         6     1000
# 11  1000_11 2018-05-28        19     1000
# 12  1000_12 2018-07-05         3     1000
# 13  1000_13 2018-09-29         8     1000
# 14  1000_14 2018-12-11        10     1000
# 15  1000_15 2018-07-27        10     1000
# 16  1000_16 2018-08-11         5     1000
# 17  1000_17 2018-08-02        13     1000
# 18  1000_18 2018-06-15         5     1000
# 19  1000_19 2018-11-02        16     1000

# %%
internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129788 entries, 0 to 149395
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            129788 non-null  object
#  1   mb_used       129788 non-null  int64
#  2   session_date  129788 non-null  datetime64[ns]
#  3   user_id       129788 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 5.0+ MB

# %%
internet.head(15)
# Out:
#          id  mb_used session_date  user_id
# 0    1000_0      113   2018-11-25     1000
# 1    1000_1     1053   2018-09-07     1000
# 2    1000_2     1198   2018-06-25     1000
# 3    1000_3      551   2018-08-22     1000
# 4    1000_4      303   2018-09-24     1000
# 5    1000_5      400   2018-10-02     1000
# 6    1000_6      541   2018-09-07     1000
# 7    1000_7      416   2018-07-11     1000
# 8    1000_8      506   2018-10-08     1000
# 9    1000_9      346   2018-09-03     1000
# 10  1000_10      386   2018-09-27     1000
# 12  1000_12      376   2018-06-20     1000
# 13  1000_13      394   2018-08-09     1000
# 14  1000_14      181   2018-08-11     1000
# 15  1000_15      338   2018-07-21     1000

# %% [markdown]
# #### Добавим столбец со значением  mont месяц в таблицы /calls /, /messages/,  /internet/<a class="tocSkip">

# %%
calls['month'] = calls['call_date'].dt.month_name()#добавляем столбец month  месяц
# Out:
# <ipython-input-67-fc6321df88c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calls['month'] = calls['call_date'].dt.month_name()#добавляем столбец month  месяц

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Добавление месяца корректно.
# </div>

# %%
calls.head(2)
# Out:
#        id  call_date  duration  user_id      month
# 2  1000_2 2018-06-11         3     1000       June
# 3  1000_3 2018-09-21        14     1000  September

# %%
messages['month'] = messages['message_date'].dt.month_name()#добавляем столбец month  месяц

# %%
messages.head(2)
# Out:
#        id message_date  user_id    month
# 0  1000_0   2018-06-27     1000     June
# 1  1000_1   2018-10-08     1000  October

# %%
internet['month'] = internet['session_date'].dt.month_name()#добавляем столбец month  месяц
# Out:
# <ipython-input-71-c2230452935c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   internet['month'] = internet['session_date'].dt.month_name()#добавляем столбец month  месяц

# %%
internet.head(2)
# Out:
#        id  mb_used session_date  user_id      month
# 0  1000_0      113   2018-11-25     1000   November
# 1  1000_1     1053   2018-09-07     1000  September

# %%
calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162994 entries, 2 to 202606
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         162994 non-null  object
#  1   call_date  162994 non-null  datetime64[ns]
#  2   duration   162994 non-null  int64
#  3   user_id    162994 non-null  int64
#  4   month      162994 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 7.5+ MB

# %% [markdown]
#  **Вывод**

# %% [markdown]
#  <div style="border:solid green 2px; padding: 20px">
#
# Необходимо сменить форматы в следующих столбцах:
#
# - В таблице **users**  изменили форматы в столбецах __churn_date__ и __reg_date__   на ___datetime___
# - В таблице __calls__ изменили формат в столбеце __call_date__   на ___datetime___
# - В таблиах __messages, internet,__ изменили  форматы в столбецах __message_date, session_date__   на ___datetime___
# - Добавили  к каждой таблице  __calls__ __messages__ __internet__  -  столбец __month__ месяц.
# - Изменили формат float на  int в столбцах   __duration__   и __mb_used__

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>
#
# С выводами согласен, только не забудь потом скорректировать вывод после корректного округления.
# </div>

# %% [markdown]
# ### Объединение таблиц.  Количественные показатели.
# [&#10224;](#step1)

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# - для подсчета ключевых метрик, необходимо произвести объединение сводных таблиц в единый датафрейм 'df'
# ### необходимо посчитать для каждого пользователя:<a class="tocSkip">
# - количество сделанных звонков и израсходованных минут разговора по месяцам;
# - количество отправленных сообщений по месяцам;
# - объем израсходованного интернет-трафика по месяцам;
# - помесячную выручку с каждого пользователя (вычтите бесплатный лимит из суммарного количества звонков, сообщений и интернет-трафика; остаток умножьте на значение из тарифного плана; прибавьте абонентскую плату, соответствующую тарифному плану).

# %% [markdown]
# #### Для слияния по столбцу  tariff,  таблиц users и tariffs,  необходимо переименовать столбец tariff_name в   tariff <a class="tocSkip">

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Переименование столбца не совсем обязательно, но допустимо. Когда будешь использовать `merge`, то можно выбрать атрибуты `left_on` и `right_on` - это ключи, по которым будут соединяться фреймы, они могут быть разными.
# </div>

# %%
users.head(3)
# Out:
#    user_id  age churn_date         city first_name  last_name   reg_date  \
# 0     1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 1     1001   41        NaT       Москва       Иван       Ежов 2018-11-01
# 2     1002   59        NaT  Стерлитамак    Евгений  Абрамович 2018-06-17
#
#   tariff
# 0  ultra
# 1  smart
# 2  smart

# %%
tariffs.columns
# Out:
# Index(['messages_included', 'mb_per_month_included', 'minutes_included',
#        'rub_monthly_fee', 'rub_per_gb', 'rub_per_message', 'rub_per_minute',
#        'tariff_name'],
#       dtype='object')

# %%
tariffs.head()
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute tariff_name
# 0              550         200                3               3       smart
# 1             1950         150                1               1       ultra

# %%
tariffs.columns = ['messages_included', 'mb_per_month_included', 'minutes_included', 'rub_monthly_fee',\
                      'rub_per_gb','rub_per_message', 'rub_per_minute', 'tariff'] 
#пререименовываем столбец tariff_name в  tariff
#tariffs.rename(columns={'tariff_name': 'tariff'}, inplace=True) # можно сделать замену через rename

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Пожалуй, второй вариант, который закомментирован более элегантный и короткий.
# </div>

# %%
tariffs.columns
# Out:
# Index(['messages_included', 'mb_per_month_included', 'minutes_included',
#        'rub_monthly_fee', 'rub_per_gb', 'rub_per_message', 'rub_per_minute',
#        'tariff'],
#       dtype='object')

# %% [markdown]
# Проверим результат

# %%
tariffs.head() # смотрим результат преобразований
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute tariff
# 0              550         200                3               3  smart
# 1             1950         150                1               1  ultra

# %% [markdown]
# ### Для подсчета ключевых  показателей  Объеденим  таблицы   `используем методы  merge и join .`<a class="tocSkip">

# %% [markdown]
# #### Соединим таблицы users и tariffs<a class="tocSkip">

# %%
users.head()# исходное состояние
# Out:
#    user_id  age churn_date         city first_name  last_name   reg_date  \
# 0     1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 1     1001   41        NaT       Москва       Иван       Ежов 2018-11-01
# 2     1002   59        NaT  Стерлитамак    Евгений  Абрамович 2018-06-17
# 3     1003   23        NaT       Москва      Белла   Белякова 2018-08-17
# 4     1004   68        NaT  Новокузнецк    Татьяна   Авдеенко 2018-05-14
#
#   tariff
# 0  ultra
# 1  smart
# 2  smart
# 3  ultra
# 4  ultra

# %%
users_tariffs = users.merge(tariffs, on='tariff', how='left')# методом merge объединякм таблицы users и tariffs

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Здесь так же необязательно прописывать каким именно типом соединения ты пользуешься, т.к. ключи в обоих фреймах без пропусков и потерь не будет.
# </div>

# %%
users_tariffs.head()# результат после объединения
# Out:
#    user_id  age churn_date         city first_name  last_name   reg_date  \
# 0     1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 1     1001   41        NaT       Москва       Иван       Ежов 2018-11-01
# 2     1002   59        NaT  Стерлитамак    Евгений  Абрамович 2018-06-17
# 3     1003   23        NaT       Москва      Белла   Белякова 2018-08-17
# 4     1004   68        NaT  Новокузнецк    Татьяна   Авдеенко 2018-05-14
#
#   tariff  messages_included  mb_per_month_included  minutes_included  \
# 0  ultra               1000                  30720              3000
# 1  smart                 50                  15360               500
# 2  smart                 50                  15360               500
# 3  ultra               1000                  30720              3000
# 4  ultra               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute
# ...

# %% [markdown]
# Использую метод pivot_table создадим сводные таблицы __звонков, сообщений и интернет-трафика,__ сгруппированные по клиентам и месяцам.

# %%
calls.head(15)
# Out:
#          id  call_date  duration  user_id      month
# 2    1000_2 2018-06-11         3     1000       June
# 3    1000_3 2018-09-21        14     1000  September
# 4    1000_4 2018-12-15         6     1000   December
# 7    1000_7 2018-08-22        19     1000     August
# 8    1000_8 2018-09-15        19     1000  September
# 10  1000_10 2018-08-22         6     1000     August
# 11  1000_11 2018-05-28        19     1000        May
# 12  1000_12 2018-07-05         3     1000       July
# 13  1000_13 2018-09-29         8     1000  September
# 14  1000_14 2018-12-11        10     1000   December
# 15  1000_15 2018-07-27        10     1000       July
# 16  1000_16 2018-08-11         5     1000     August
# 17  1000_17 2018-08-02        13     1000     August
# 18  1000_18 2018-06-15         5     1000       June
# 19  1000_19 2018-11-02        16     1000   November

# %% [markdown]
# #### Определим количество  звонков и израсходованных минут разговора по месяцам <br>
#
# `2.Таблица` ____calls____ — (информация о звонках):<br>
# - **id** — уникальный номер звонка
# - **call_date** — дата звонка
# - **duration** — длительность звонка в минутах
# - **user_id** — идентификатор пользователя, сделавшего звонок<br>

# %% [markdown]
# ####   -  Количество сделанных звонков и израсходованных минут разговора по месяцам.<a class="tocSkip">

# %%
# методом pivot_table в сводной таблице группируем звонки по клиентам и месяцам, определяе количество сделанных звонков
# и исользованных минут.
calls_summary = calls.pivot_table(index=['user_id', 'month'], values='duration', aggfunc=['count', 'sum'])
calls_summary.columns = ['calls', 'minutes']
calls_summary.head(10)
# Out:
#                    calls  minutes
# user_id month
# 1000    August        42      408
#         December      38      333
#         July          41      340
#         June          28      172
#         May           17      159
#         November      37      338
#         October       44      350
#         September     46      466
# 1001    December      47      414
#         November      45      430

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Группировка данных произведена корректно. Супер, что используешь `pivot_table`, в данном случае, он более интуитивно понятный и в некоторых случаях может занять гораздо меньше строк кода при сложных группировках относительно `groupby`. В идеале желательно владеть обоими инструментами.
# </div>

# %% [markdown]
# ---

# %% [markdown]
# #### Определим количество  отправленных сообщений по месяцам <br>
#
# `3.Таблица` ___messages___ — (информация о сообщениях):<br>
# - **id** — уникальный номер сообщения
# - **message_date** — дата сообщения
# - **user_id** — идентификатор пользователя, отправившего сообщение<br>

# %% [markdown]
# ####   - Количество отправленных сообщений по месяцам.<a class="tocSkip">

# %%
# методом pivot_table в сводной таблице группируем стс сообщения  по клиентам и месяцам, определяе количество  сообщений 
messages_summary = messages.pivot_table(index=['user_id', 'month'], values='id', aggfunc='count')
messages_summary.columns = ['sms']
messages_summary.head(10)
# Out:
#                    sms
# user_id month
# 1000    August      81
#         December    70
#         July        75
#         June        60
#         May         22
#         November    58
#         October     73
#         September   57
# 1002    August      13
#         December    12

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Группировка так же произведена корректно.
# </div>

# %% [markdown]
# ---

# %% [markdown]
# #### Определим объем израсходованного интернет-трафика по месяцам<br>
#
# `4.Таблица` ___internet___ — (информация об интернет-сессиях):<br>
# - **id** — уникальный номер сессии
# - **mb_used** — объём потраченного за сессию интернет-трафика (в мегабайтах)
# - **session_date** — дата интернет-сессии
# - **user_id** — идентификатор пользователя<br>

# %% [markdown]
# ####   - Объем израсходованного интернет-трафика по месяцам.<a class="tocSkip">

# %%
# методом pivot_table в сводной таблице группируем интернет-трафик  по клиентам и месяцам, определяе количество
# использованных  мегабайт в месяц.
internet_summary = internet.pivot_table(index=['user_id', 'month'], values='mb_used', aggfunc='sum')
internet_summary.head(10)
# Out:
#                    mb_used
# user_id month
# 1000    August       14070
#         December      9827
#         July         14016
#         June         23257
#         May           2256
#         November     14768
#         October      14717
#         September    14581
# 1001    December     14053
#         November     18452

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Группировка так же произведена корректно.
# </div>

# %% [markdown]
# ---

# %% [markdown]
# Методом join, по общим столбцам 'user_id','month'  объединим полученные сводные таблицы 'internet_summary','calls_summary', 'messages_summary'  в единый датафрейм  'summary_table'

# %%
df_summary = [internet_summary,calls_summary, messages_summary] # проверим количество строк в сгруппированных таблицах, перед объединением таблиц.
for i in df_summary:
    display(i.shape)
# Out:
# (3201, 1)
# (3168, 2)
# (2717, 1)

# %% [markdown]
# В нашем случае строк в __internet_summary__(3201) больше чем в __calls_summary__(3168) и __messages_summary__(2717) . Порядок объединения будет следующим: internet_summary/calls_summary/messages_summary

# %%
summary_table = internet_summary.join(calls_summary, on=['user_id','month'], how='left')\
.join(messages_summary, on=['user_id','month'], how='left')

# %% [markdown]
# <div style="border:solid light blue 1px; padding: 1px">
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Выше код исправлен после замечания ревьювера.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера V2:</b>
#
# В данном случае следовало оценить именно кол-во уникальных клиентов в сгруппированных данных, а не полное кол-во строк. Здесь тебе повезло, что эти соотношения сохранились и порядок коректен. Но могло бы получиться и так, что  например у интернета больше строк, но там клиентов будет меньше - просто на каждого клиента больше записей вышло.
# </div>

# %% [raw]
# Ошибочное решение !!!
#
# summary_table = calls_summary.join(messages_summary, on=['user_id','month'], how='left')\
# .join(internet_summary, on=['user_id','month'], how='left')

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера:</b>
#
# В этом случае, отлично, что указываешь тип соединения `how`, т.к. данных могут потеряться, но не учитываешь одного нюанса. Ты соединяешь по юзерам и они тебя больше всего интересуют, но вот в каждом из датасетов кол-во уникальных юзеров разное, а значит важное значение будет иметь порядок джойнов. По этому, чтобы корректно соединить датафреймы в итоговый нужно:
#
# 1. Проверить кол-во уникальных юзеров в сгруппированных выборках
# 2. Соединять датафреймы по порядку от большего к меньшему. То есть если в `internet_summary` уникальных юзеров больше, чем в `calls_summary`, то нужно джойнить их в том же порядке.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Совет по красивому написанию кода. Если ты используешь лестничное написание с помощью `\`, то лучше будет выглядеть так:
#
# ```python
# summary_table = calls_summary\
#                 .join(messages_summary, on=['user_id','month'], how='left')\
#                 .join(internet_summary, on=['user_id','month'], how='left')
# ```
# </div>

# %%
summary_table
# Out:
#                    mb_used  calls  minutes   sms
# user_id month
# 1000    August       14070  42.00   408.00 81.00
#         December      9827  38.00   333.00 70.00
#         July         14016  41.00   340.00 75.00
#         June         23257  28.00   172.00 60.00
#         May           2256  17.00   159.00 22.00
# ...                    ...    ...      ...   ...
# 1498    September    22166  53.00   471.00 44.00
# 1499    December     13077  56.00   492.00 66.00
#         November     17984  62.00   612.00 59.00
#         October      17809  44.00   449.00 48.00
#         September     1848   8.00    70.00 11.00
#
# [3201 rows x 4 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="border:solid light blue 1px; padding: 1px">
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
#   Нашлись 33 строки. Хорошо, лестничное написание и порядок соединение  учту!
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера V2:</b>
#
# Да, супер.
# </div>

# %% [markdown]
# Полученнную сводную таблицу __'summary_tablе'__ соеденим методом  __merge__ (для полной наглядности) с датафреймом __'users_tariffs'__ полученным ранее. Полученную таблицу назовем __'df'__

# %%
df = users_tariffs.merge(summary_table, on='user_id', how='left')# методом merge объеденим таблицы  users_tariffs b summary_table

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3204 entries, 0 to 3203
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                3204 non-null   int64
#  1   age                    3204 non-null   int64
#  2   churn_date             188 non-null    datetime64[ns]
#  3   city                   3204 non-null   object
#  4   first_name             3204 non-null   object
#  5   last_name              3204 non-null   object
#  6   reg_date               3204 non-null   datetime64[ns]
#  7   tariff                 3204 non-null   object
#  8   messages_included      3204 non-null   int64
#  9   mb_per_month_included  3204 non-null   int64
#  10  minutes_included       3204 non-null   int64
#  11  rub_monthly_fee        3204 non-null   int64
#  12  rub_per_gb             3204 non-null   int64
#  13  rub_per_message        3204 non-null   int64
# ...

# %% [markdown]
# <div style="border:solid light blue 1px; padding: 1px">
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Выше код исправлен после замечания ревьювера.<br>
# После изменения порядка соединения таблиц, добавилось еще 3 строки, слетели корректные форматы, добавилиь пропуски.&#128528;
# </div>

# %% [raw]
# Ошибочное решение !!!
#
# # методом join объединякм таблицы summary_table и users_tariffs
# df = summary_table.join(users_tariffs.set_index('user_id'), on='user_id', how='left')

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера:</b>
#
# Здесь аналогичная ситуация с порядком джойнов. Если ты выбираешь `left`, тогда нужно джойнить от большего к меньшему. У тебя в `users_tariffs` инфа точно на всех юзеров представлена, тогда он должен быть первый по порядку.
# </div>

# %% [markdown]
# <div style="border:solid light blue 1px; padding: 1px">
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Кто-то полагает, что всякие мерджи, джойны -  "Адовы муки". Заблуждаются! Думаю это "Самое сердце Преисподней". Яндекс четко знает, а смертные, могут только вероятностные (неутешительные) предположения строить, сколькож здесь народу полегло!?)).
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера V2:</b>
#
# Хах, это точно😀. Кстати тут не так уж и сложно по идее, надо было `outer` использовать в типе соединения. Почитай про него и многие потери сами собой испорятся и не надо мудить с порядком. Порядок важен именно при `left`, `right`. Самое главное, что сейчас все корректно.
# </div>

# %%
df
# Out:
#       user_id  age churn_date         city first_name  last_name   reg_date  \
# 0        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 1        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 2        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 3        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 4        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# ...       ...  ...        ...          ...        ...        ...        ...
# 3199     1498   68 2018-10-25  Владикавказ   Всеволод    Акимчин 2018-07-19
# 3200     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
# 3201     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
# 3202     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
# 3203     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
#
# ...

# %% [markdown]
# Проверим полученный датафрейм на пропуски и дубликаты

# %%
report = df.isna().sum().to_frame()
report = report.rename(columns = {0: 'missing_values'})
report['% of total'] = (report['missing_values'] / df.shape[0]).round(2)
report.sort_values(by = 'missing_values', ascending = False)
# Out:
#                        missing_values  % of total
# churn_date                       3016        0.94
# sms                               500        0.16
# minutes                            49        0.02
# calls                              49        0.02
# mb_used                             3        0.00
# minutes_included                    0        0.00
# rub_per_minute                      0        0.00
# rub_per_message                     0        0.00
# rub_per_gb                          0        0.00
# rub_monthly_fee                     0        0.00
# user_id                             0        0.00
# age                                 0        0.00
# messages_included                   0        0.00
# tariff                              0        0.00
# reg_date                            0        0.00
# last_name                           0        0.00
# first_name                          0        0.00
# city                                0        0.00
# ...

# %% [markdown]
# Проверим таблицу на дубликаты

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3204 entries, 0 to 3203
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                3204 non-null   int64
#  1   age                    3204 non-null   int64
#  2   churn_date             188 non-null    datetime64[ns]
#  3   city                   3204 non-null   object
#  4   first_name             3204 non-null   object
#  5   last_name              3204 non-null   object
#  6   reg_date               3204 non-null   datetime64[ns]
#  7   tariff                 3204 non-null   object
#  8   messages_included      3204 non-null   int64
#  9   mb_per_month_included  3204 non-null   int64
#  10  minutes_included       3204 non-null   int64
#  11  rub_monthly_fee        3204 non-null   int64
#  12  rub_per_gb             3204 non-null   int64
#  13  rub_per_message        3204 non-null   int64
# ...

# %%
# удалим пропуски и вернем целоцисленный формат в столбцах sms и mb_used 
df['sms'] = df['sms'].fillna(value= 0).astype('int64')# методом fillna пропуски заполняем  значением 0
# методом .astype() для столбца sms устан формат int64   
df['mb_used'] = df['mb_used'].fillna(value= 0).astype('int64') # методом fillna пропуски заполняем  значением 0
# методом .astype() для столбца mb_used устан формат int64
df['calls'] = df['calls'].fillna(value= 0).astype('int64') #
df['minutes'] = df['minutes'].fillna(value= 0).astype('int64') #

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# С заполнением пустых значений в результате преобразований согласен.
# </div>

# %% [markdown]
# Проверим изменеия форматов на int и удаление пропусков в  столбцах sms и  mb_used

# %%
report = df.isna().sum().to_frame()
report = report.rename(columns = {0: 'missing_values'})
report['% of total'] = (report['missing_values'] / df.shape[0]).round(2)
report.sort_values(by = 'missing_values', ascending = False)
# Out:
#                        missing_values  % of total
# churn_date                       3016        0.94
# user_id                             0        0.00
# minutes_included                    0        0.00
# minutes                             0        0.00
# calls                               0        0.00
# mb_used                             0        0.00
# rub_per_minute                      0        0.00
# rub_per_message                     0        0.00
# rub_per_gb                          0        0.00
# rub_monthly_fee                     0        0.00
# mb_per_month_included               0        0.00
# age                                 0        0.00
# messages_included                   0        0.00
# tariff                              0        0.00
# reg_date                            0        0.00
# last_name                           0        0.00
# first_name                          0        0.00
# city                                0        0.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3204 entries, 0 to 3203
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                3204 non-null   int64
#  1   age                    3204 non-null   int64
#  2   churn_date             188 non-null    datetime64[ns]
#  3   city                   3204 non-null   object
#  4   first_name             3204 non-null   object
#  5   last_name              3204 non-null   object
#  6   reg_date               3204 non-null   datetime64[ns]
#  7   tariff                 3204 non-null   object
#  8   messages_included      3204 non-null   int64
#  9   mb_per_month_included  3204 non-null   int64
#  10  minutes_included       3204 non-null   int64
#  11  rub_monthly_fee        3204 non-null   int64
#  12  rub_per_gb             3204 non-null   int64
#  13  rub_per_message        3204 non-null   int64
# ...

# %%
df
# Out:
#       user_id  age churn_date         city first_name  last_name   reg_date  \
# 0        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 1        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 2        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 3        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 4        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# ...       ...  ...        ...          ...        ...        ...        ...
# 3199     1498   68 2018-10-25  Владикавказ   Всеволод    Акимчин 2018-07-19
# 3200     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
# 3201     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
# 3202     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
# 3203     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
#
# ...

# %% [markdown]
# #### Определим  помесячную выручку с каждого пользователя
# - ***Посчитаем помесячную выручку от клиента сопоставив данные из его тарифного плана и количества использованных им услуг.***<br>
# (вычтем бесплатный лимит из суммарного количества звонков, сообщений и интернет - трафика; остаток умножем на значение из тарифного плана; прибавим абонентскую плату, соответствующую тарифному плану).

# %%
df.head()
# Out:
#    user_id  age churn_date       city first_name  last_name   reg_date tariff  \
# 0     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 1     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 2     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 3     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 4     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
#
#    messages_included  mb_per_month_included  minutes_included  \
# 0               1000                  30720              3000
# 1               1000                  30720              3000
# 2               1000                  30720              3000
# 3               1000                  30720              3000
# 4               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute  mb_used  \
# ...

# %% [markdown]
# Для вычисления месячной выручки создадим функцию 'revenue' c помощью которой определим разницу между включенными в тариф  и перерасходованными объемами услуг.

# %%
def revenue(minutes, minutes_included, rub_per_minute, sms, messages_included,
                   rub_per_message, mb_used, mb_per_month_included, rub_per_gb,
                   rub_monthly_fee):
    
    if minutes > minutes_included:
        over_calls = (minutes - minutes_included)*rub_per_minute
    else:
        over_calls = 0
        
        
    if sms > messages_included:
        over_sms = (sms - messages_included)*rub_per_message
    else:
        over_sms = 0
        
        
    if mb_used > mb_per_month_included:
        over_internet = ((mb_used - mb_per_month_included)/1024)*rub_per_gb
    else:
        over_internet = 0  
    
    over_month = rub_monthly_fee + over_calls + over_sms + over_internet
    
    return over_month

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Замечательная функция. Супер, что смог учесть все параметры и уместить все в одном месте.
# </div>

# %%
df['monthly_payment'] = df.apply(lambda row: 
                                     revenue(row['minutes'],
                                     row['minutes_included'],
                                     row['rub_per_minute'],
                                     row['sms'],
                                     row['messages_included'],
                                     row['rub_per_message'],
                                     row['mb_used'],
                                     row['mb_per_month_included'],
                                     row['rub_per_gb'], row['rub_monthly_fee']), axis=1)

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# С точки зрения кода все оптимально, корректно и наглядно, молодец.
# </div>

# %%
df['monthly_payment']
# Out:
# 0      1,950.00
# 1      1,950.00
# 2      1,950.00
# 3      1,950.00
# 4      1,950.00
#          ...
# 3199   1,879.30
# 3200     598.00
# 3201   1,425.50
# 3202   1,028.32
# 3203     550.00
# Name: monthly_payment, Length: 3204, dtype: float64

# %% [markdown]
# Изменим в получившемся столбце вещественный формат float на целочисленны int

# %%
df['monthly_payment'] = df['monthly_payment'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3204 entries, 0 to 3203
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                3204 non-null   int64
#  1   age                    3204 non-null   int64
#  2   churn_date             188 non-null    datetime64[ns]
#  3   city                   3204 non-null   object
#  4   first_name             3204 non-null   object
#  5   last_name              3204 non-null   object
#  6   reg_date               3204 non-null   datetime64[ns]
#  7   tariff                 3204 non-null   object
#  8   messages_included      3204 non-null   int64
#  9   mb_per_month_included  3204 non-null   int64
#  10  minutes_included       3204 non-null   int64
#  11  rub_monthly_fee        3204 non-null   int64
#  12  rub_per_gb             3204 non-null   int64
#  13  rub_per_message        3204 non-null   int64
# ...

# %% [markdown]
# Определим разницу между абонентской платой по тарифу и суммами появившимися при перерасходе услуг сверх тарифа. Вычтем из 'monthly_payment' - 'rub_monthly_fee' сохраним получивщийся результат в таблицу 'overpayment'

# %%
df['overpayment'] = df['monthly_payment'] - df['rub_monthly_fee']

# %%
df.head(15)
# Out:
#     user_id  age churn_date         city first_name  last_name   reg_date  \
# 0      1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 1      1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 2      1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 3      1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 4      1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 5      1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 6      1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 7      1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 8      1001   41        NaT       Москва       Иван       Ежов 2018-11-01
# 9      1001   41        NaT       Москва       Иван       Ежов 2018-11-01
# 10     1002   59        NaT  Стерлитамак    Евгений  Абрамович 2018-06-17
# 11     1002   59        NaT  Стерлитамак    Евгений  Абрамович 2018-06-17
# ...

# %%
df
# Out:
#       user_id  age churn_date         city first_name  last_name   reg_date  \
# 0        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 1        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 2        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 3        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 4        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# ...       ...  ...        ...          ...        ...        ...        ...
# 3199     1498   68 2018-10-25  Владикавказ   Всеволод    Акимчин 2018-07-19
# 3200     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
# 3201     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
# 3202     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
# 3203     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
#
# ...

# %% [markdown]
# **Вывод**

# %% [markdown]
#  <div style="border:solid green 2px; padding: 20px">
#
# Таблицы объеденены, форматы исправлены, пропуски частичтно заменены на значение 0. Получили наглядную таблицу с пользователями и необходимыми для дальнейших расчетов показателями о количестве звонков, отправленных сообщениях и использованном интернет трафике по месяцам. Определили и добавили в таблицу столбецы с платежами в месяц и переплатой по каждому клиенту.  Появление пропусков, скорей всего,  связано с тем, что абонент   не  пользовался определенной услугой.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Выводы корректны и понятны, отлично.
# </div>

# %% [markdown]
# ## Исследовательский анализ данных
# [&#10224;](#step1)

# %% [markdown]
#  <div style="border:solid green 2px; padding: 20px">
#
# ## Опишем поведение клиентов оператора  исходя из выборки.<a class="tocSkip">
#
#
# - сколько требуется минут разговора, сколько необходимо сообщений  и какой объём интернет-трафика требуется пользователям каждого тарифа в месяц?
# - посчитаем среднее количество, дисперсию и стандартное отклонение. Построим  гистограммы. Опишем распределения.

# %% [markdown]
# ### Проведем исследовательский анализ данных построим графики и гистаграммы для получения ответов в поставленной задаче.
# [&#10224;](#step1)

# %% [markdown]
# Определим распределение клиентов по тарфным планам.

# %%
users_tariff = users['tariff'].value_counts().to_frame()# методом value_counts определим количество абонентов по каждому тарифу
users_tariff
# Out:
#        tariff
# smart     351
# ultra     149

# %%
users_tariff.plot(kind='bar',figsize =(7,5),grid=True,title='Количество пльзователей тарифов смарт и ультра')

plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Для количественного отображения барплот отлично подходит.
# </div>

# %%
percent_tariffs = ((users_tariff['tariff']/500)*100).round(1).to_frame()
percent_tariffs
# Out:
#        tariff
# smart   70.20
# ultra   29.80

# %%
percent_tariffs.plot(kind='bar',figsize =(7,5),grid=True,title='% пльзователей тарифов смарт и ультра')

plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# А вот для отражения долевого соотношения лучше бы подошел пайплот `pie`.
# </div>

# %% [markdown]
# <div style="border:solid light blue 1px; padding: 1px">
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# честно, не понял pie, если имеещь ввиду круговую диаграмму, то  пока не овладел(  Если только так, ручками..
#
#
# </div>

# %%
labels = 'smart', 'ultra'
sizes = [70.20, 29.80]

fig1, ax1 = plt.subplots()
explode = (0, 0.1) 
ax1.pie(sizes, explode=explode, labels=labels,autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.set_title("Процентное соотношение тарифов Смарт и  Ультра")
plt.show()

# %% [markdown]
# Тариф "Смарт" пользуется большей популярностью его доля в выборку составила (351 абонент или 70.2%) , тарифу "Ультра" соответственно остается (149 абонент или 29,8%) Можно предположить, что разница почти в 2.5 раза между "Смартом" и "Ультра" обусловленна изначально привлекательной ценой первого.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера V2:</b>
#
# Да, именно его и имел в виду - супер.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Согласен, вывод вполне обоснованный - смарт же дешевле, а русский народ - он и есть русский народ😃
# </div>

# %% [markdown]
# Посмотрим распределение клиентов по городам

# %%
top_sity = users['city'].value_counts().head(30)
top_sity
# Out:
# Москва              99
# Санкт-Петербург     39
# Новосибирск         16
# Омск                14
# Казань              14
# Уфа                 12
# Ульяновск           11
# Екатеринбург        11
# Набережные Челны    11
# Краснодар           11
# Челябинск            9
# Самара               9
# Пермь                8
# Волгоград            8
# Нижний Новгород      8
# Улан-Удэ             7
# Вологда              7
# Новокузнецк          7
# Красноярск           7
# Томск                6
# Тюмень               6
# Иркутск              6
# Киров                6
# Воронеж              6
# Пенза                6
# Сочи                 6
# Ростов-на-Дону       6
# Магнитогорск         5
# Махачкала            5
# Балашиха             5
# Name: city, dtype: int64

# %%
top_sity.plot(kind='bar',figsize =(12,7),grid=True,title='30 крупнейших насленных пунктов по числу пользователей')

plt.show()

# %% [markdown]
# Видим, что основные клиенты - Москва и Санкт-Петербург.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Круто, что выводишь доп. информацию, которая не требуется в задании. Действительно, интересно посмотреть такие группировки и поискать инсайты.
# </div>

# %% [markdown]
# Посмотрим топ 30 городов где максимально клиенты переплачивают.

# %%
group_over_city = df.groupby('city')['overpayment'].agg(['median','mean','min','max','count','sum'])\
.sort_values('max', ascending = False).head(30)
#группируем города  по  переплатам , сортируем в конце по количеству переплат из городов
group_over_city
# Out:
#                    median     mean  min   max  count     sum
# city
# Нижний Новгород    248.50   734.61    0  6161     54   39669
# Казань             243.00   565.81    0  5108     77   43567
# Хабаровск          563.00   996.95    0  5028     19   18942
# Москва              49.00   441.52    0  4636    611  269768
# Красноярск         383.50   746.26    0  4572     46   34328
# Челябинск            0.00   546.35    0  4406     51   27864
# Чита               434.00   623.89    0  3828     18   11230
# Волгоград          189.00   469.66    0  3771     59   27710
# Санкт-Петербург    361.00   704.07    0  3749    270  190098
# Ростов-на-Дону     292.00   604.10    0  3738     29   17519
# Екатеринбург        76.50   503.50    0  3715     42   21147
# Череповец          741.00 1,223.07    0  3541     14   17123
# Саратов              0.00   547.21    0  3390     19   10397
# Саранск          1,001.00   978.55    0  3336     22   21528
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Очень наглядная группировка. Кроме Питера и Москвы есть лидеры, которые сменились после подсчета обычного кол-ва клиентов по городам?
# </div>

# %% [markdown]
# <div style="border:solid light blue 1px; padding: 1px">
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
#  Да,  смотрел на этот момент, когда менял в .sort_values способы сортировки. При группировке по sum и count на своих местах остаются только Москва, Питер, Новосибирск - ниже пляски. mean и max  свои лидеры. Есть кто не платил min 0 (надо подумать над этим нулем, он сильно корректирует выводы!)
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера V2:</b>
#
# Интересненько, в любом случае, он очень классный инсайт.
# </div>

# %%
df.groupby('city')['overpayment'].agg(['sum']).sort_values('sum', ascending = False).head(30).plot(kind='bar',figsize =(12,7),grid=True,title='Переплаты по городам ')
plt.show()

# %% [markdown]
# Посмотрим какой объем выручки и по каким тарифам приносят абоненты компании "Мегалайн"

# %%
df['monthly_payment'].sum()# полная выручка компании за год по всем тарифам (с учетом оплаты перерасходованных объемов)
# Out:
# 4759940

# %%
df.groupby('tariff')['monthly_payment'].agg(['sum','max','min','median','mean']).head(60)
# смотрим сколько всего приносят компании тарифы Смарт и Ультра
# Out:
#             sum   max   min  median     mean
# tariff
# smart   2747934  6711   550     960 1,233.36
# ultra   2012006  4743  1950    1950 2,061.48

# %%
df['overpayment'].sum()# дополнительная выручуа компании по всем тарифам
# Out:
# 1631340

# %%
df.groupby('tariff')['overpayment'].agg(['sum','max','min','median','mean']).head(60)
# смотрим сколько дополнительно приносят компании тарифы Смарт и Ультра
# Out:
#             sum   max  min  median   mean
# tariff
# smart   1522534  6161    0     410 683.36
# ultra    108806  2793    0       0 111.48

# %%
df['not_over'] = df['monthly_payment'] - df['overpayment']# создадим столбец  not_over в котором отразим выручку без переплат

# %%
df['not_over'].sum()# вся выручка компании без дополнительных оплат перерасходованных услуг.
# Out:
# 3128600

# %%
df.groupby('tariff')['not_over'].agg(['sum','max','min','median','mean']).head(60)
# смотрим сколько  приносят компании тарифы Смарт и Ультра по их абонентским платам
# Out:
#             sum   max   min  median  mean
# tariff
# smart   1225400   550   550     550   550
# ultra   1903200  1950  1950    1950  1950

# %%
users_tariff = users['tariff'].value_counts().to_frame()# методом value_counts определим количество абонентов по каждому тарифу
users_tariff
# Out:
#        tariff
# smart     351
# ultra     149

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Приведенные группировки по итоговым выручкам очень наглядны, не хватает только своевременных промежуточных выводов, чтобы на месте оценивать результат.
# </div>

# %% [markdown]
#  Посмотрим на полученные результаты еще раз, с помощью срезов. Сделаем срез по общим доходам в обоих тарифах

# %%
pay_tariff = df.query('monthly_payment > 0')
pay_tariff.head()
# Out:
#    user_id  age churn_date       city first_name  last_name   reg_date tariff  \
# 0     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 1     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 2     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 3     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 4     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
#
#    messages_included  mb_per_month_included  minutes_included  \
# 0               1000                  30720              3000
# 1               1000                  30720              3000
# 2               1000                  30720              3000
# 3               1000                  30720              3000
# 4               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute  mb_used  \
# ...

# %%
pay_tariff.groupby('tariff')['monthly_payment'].agg(['median','mean','min','max','count','sum'])\
.sort_values('count', ascending = False)
#группируем тарифы  по  общей выручке , сортируем в конце по количеству выручек из тарифов
# Out:
#         median     mean   min   max  count      sum
# tariff
# smart      960 1,233.36   550  6711   2228  2747934
# ultra     1950 2,061.48  1950  4743    976  2012006

# %% [markdown]
# Сделаем срез по переплатам в обоих тарифах

# %%
over_tariff = df.query('overpayment > 0')
over_tariff.head()
# Out:
#     user_id  age churn_date         city first_name  last_name   reg_date  \
# 9      1001   41        NaT       Москва       Иван       Ежов 2018-11-01
# 10     1002   59        NaT  Стерлитамак    Евгений  Абрамович 2018-06-17
# 11     1002   59        NaT  Стерлитамак    Евгений  Абрамович 2018-06-17
# 12     1002   59        NaT  Стерлитамак    Евгений  Абрамович 2018-06-17
# 14     1002   59        NaT  Стерлитамак    Евгений  Абрамович 2018-06-17
#
#    tariff  messages_included  mb_per_month_included  minutes_included  \
# 9   smart                 50                  15360               500
# 10  smart                 50                  15360               500
# 11  smart                 50                  15360               500
# 12  smart                 50                  15360               500
# 14  smart                 50                  15360               500
#
#     rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute  mb_used  \
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Интересно было бы посмотреть соотношение: как сильно зависит выручка от кол-ва пользователей, возможно только 50% пользователей приносят весь доход)
# </div>

# %%
group_over = over_tariff.groupby('tariff')['overpayment'].agg(['median','mean','min','max','count','sum'])\
.sort_values('count', ascending = False)
#группируем тарифы  по  переплатам , сортируем в конце по количеству переплат из тарифов
group_over
# Out:
#         median   mean  min   max  count      sum
# tariff
# smart      728 914.43    1  6161   1665  1522534
# ultra      653 811.99   41  2793    134   108806

# %% [markdown]
# Сделаем срез по основному доходу(абонентская плата) в обоих тарифах

# %%
basic_tariff = df.query('not_over > 0')
basic_tariff.head()
# Out:
#    user_id  age churn_date       city first_name  last_name   reg_date tariff  \
# 0     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 1     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 2     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 3     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 4     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
#
#    messages_included  mb_per_month_included  minutes_included  \
# 0               1000                  30720              3000
# 1               1000                  30720              3000
# 2               1000                  30720              3000
# 3               1000                  30720              3000
# 4               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute  mb_used  \
# ...

# %%
basic_tariff.groupby('tariff')['not_over'].agg(['median','mean','min','max','count','sum'])\
.sort_values('count', ascending = False)
#группируем тарифы  по основным доходам  , сортируем в конце по количеству доходов  из тарифов
# Out:
#         median  mean   min   max  count      sum
# tariff
# smart      550   550   550   550   2228  1225400
# ultra     1950  1950  1950  1950    976  1903200

# %% [markdown]
# построим гистограмму переплат по тарифу Смарт

# %%
gist_smart = df.query('tariff == "smart" and overpayment > 0')

# %%
gist_smart.plot(y='overpayment', kind='hist',title='Переплата по тарифу смарт',bins=130, legend=False, grid=True, xlim=(0,1000))
plt.show()

# %% [markdown]
# построим гистограмму переплат по тарифу Ультра

# %%
gist_ultra = df.query('tariff == "ultra" and overpayment > 0')

# %%
gist_ultra.plot(y='overpayment', kind='hist',title='Переплата по тарифу ультра',bins=130, legend=False, grid=True, xlim=(0,1000) )
plt.show()

# %% [markdown]
# Еще раз посмотрим на распределение по общей выручке, построим график.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>
#
# Добавить бы прямо здесь анализ этих гистограмм, какие есть принципиальные отличия.
# </div>

# %% [markdown]
# <div style="border:solid light blue 1px; padding: 1px">
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
#  Основная масса в тарифе Смар стабильно  переплачивает 50-180 руб., но есть всплески на 400, 600, 800 рублей. (возможно связано с 200 руб за 1Гб.).Им также постоянно не хватает минут и они регулярно, по убыванию величины платежа, тратят деньги на связь.
# В тарифе Ультра этой стабильности не наблюдается, есть разрозненные всплески. Мы выяснили, что здесь  минут  хватает практически всем, и если есть доплаты, то незначительные.  Основные платежи - это  дополнительные Гигабайты,  и  в районе 300 рублей всплеск возможен по схожим причинам, что и в Смарте, докупил 2Гб - отдал 300 рублей.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера V2:</b>
#
# Отлично. Приятно, что обращаешься внимания на все комменты.
# </div>

# %%
total_revenue= df.groupby('tariff')['monthly_payment'].sum().to_frame()
total_revenue
# Out:
#         monthly_payment
# tariff
# smart           2747934
# ultra           2012006

# %%
total_revenue.plot(kind='bar',figsize =(7,5),grid=True,title='Выручка по тарифам Смарт и Ультра')
plt.show()

# %%
#1
labels = 'Смарт', 'Ультра'
sizes = [2747934, 2012006]


fig1, ax1 = plt.subplots()
explode = (0, 0.1) 
ax1.pie(sizes,  explode=explode, labels=labels,autopct='%1.1f%%',shadow=True, startangle=90)

 
ax1.set_title("Вся выручка по тарифам Смарт Ультра ")
plt.show()

#2
labels = 'Смарт', 'Ультра'
sizes = [1522534, 108806]


fig1, ax1 = plt.subplots()
explode = (0, 0.4) 
ax1.pie(sizes,  explode=explode, labels=labels,autopct='%1.1f%%',shadow=True, startangle=30)

 
ax1.set_title("Дополнительные доходы по тарифам Смарт Ультра ")
plt.show()

#3
labels = 'Смарт', 'Ультра'
sizes = [1225400, 1903200]


fig1, ax1 = plt.subplots()
explode = (0, 0.1) 
ax1.pie(sizes,  explode=explode, labels=labels,autopct='%1.1f%%',shadow=True, startangle=90)

 
ax1.set_title("Основной доход (абонентская плата) по тарифам Смарт Ультра ")
plt.show()

# %% [markdown]
# Сформируем таблицу с общей суммой по ключевым позициям.

# %%
services = df.pivot_table(index='tariff', values=['monthly_payment','overpayment','sms','not_over','minutes','mb_used', 'calls'], aggfunc='sum')
services
# Out:
#          calls   mb_used  minutes  monthly_payment  not_over  overpayment  \
# tariff
# smart   104637  36174853   931484          2747934   1225400      1522534
# ultra    58066  19194596   516399          2012006   1903200       108806
#
#           sms
# tariff
# smart   74411
# ultra   48343

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Общее кол-во посчитано верно, не хватает только небольших корректировок с верным округлением и верным соединением датафреймов.
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="border:solid light blue 1px; padding: 1px">
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Сделал скрин, чтобы сравнить после корректировки.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера V2:</b>
#
# Да, супер, округление не сильно влияет на картину, но корректность действия обязана быть на месте.
# </div>

# %% [markdown]
# Соберем поближе основные цифры, для редактирования выводов  изменившихся после корректного округления и объединения таблиц.

# %%
pay = [df['monthly_payment'] ,df['not_over'], df['overpayment']]
for i in pay:
    display(i.sum())# для корректировки цифр в выводах
    
pd.concat([users_tariff.rename(columns={'tariff':'count_clients'})
           , percent_tariffs.rename(columns={'tariff':'%_clients'})
           , services], axis=1)#.style.bar(subset=a.columns[:2], color='lightgreen')\
                                     #.bar(subset=a.columns[2:], color='#ee1f5f')
# Out:
# 4759940
# 3128600
# 1631340
#         count_clients  %_clients   calls   mb_used  minutes  monthly_payment  \
# tariff
# smart             351      70.20  104637  36174853   931484          2747934
# ultra             149      29.80   58066  19194596   516399          2012006
#
#         not_over  overpayment    sms
# tariff
# smart    1225400      1522534  74411
# ultra    1903200       108806  48343

# %% [markdown]
# ***Вывод***

# %% [markdown]
# ***Общий доход копании по тарифам Смарт и Ультра:***
# - Общий доход компании за год сосавляет __4 759 940__ рублей из них - Тариф __Смарт__  приносит __2 747 934__ рублей. Это - __57.7%__ от всей выручки компании. Тариф __Ультра__ увеличивает счет компании за год на  __1 952 610__ рублей., что в процентном отошении состовляет __42.3%__. Тариф Cмарт почти в  __1.5__ раза  больше приносит выручки  чем тариф Ультра по общим доходам.
#
# ***Дополнительны доход копании по тарифам Смарт и Ультра:***
# - Дополнительны доход компании за год сосавляет __1 631 340__ рублей из них - Тариф __Смарт__  приносит дополнительный доход, помимо абонентской платы  __1 522 534__ рублей. Это - __93.3%__ от всей __дополнительной__ выручки компании. Тариф __Ультра__ увеличивает счет компании за счет оплат сверх тарифного плана в год на  __108 806__ рублей. что в процентном отошении состовляет  всего __6.7%__.  Дополнительный доход компании 'Мегалайн' по тарифному плану Cмарт приносит в __14__ раз больше выручки, чем тариф Ультра.
#
# ***Доход копании по тарифам Смарт и Ультра без учета дополнительных переплат:***
# - Основной доход компании от абонентской платы за год  составил __3 128 700__ рублей из них - Тариф __Смарт__ по абонентской плате  приносит основной доход компании в размере   __1 225 400__ рублей. Это - __39.2%__ от всей __основной__ выручки компании. Тариф __Ультра__ увеличивает счет компании за счет оплат сверх тарифного плана в год на  __1 903 200__ рублей. что в процентном отошении состовляет  __60.8%__ от всей основной выручки. Здесь заметна обратная ситуация, той, которую мы наблюдали с __дополнительными доходами__   Основной  доход компании 'Мегалайн' по тарифному плану Ультра приносит в __1.5__ раз больше выручки, чем тариф Смарт.
#
#
#
# - Абонентская плата по тарифу Смарт составляет 550 рублей и это по сравнению с тарифом (Ультра 1950 рублей ) в 3,5 разам меньше. Людей привлекает изначально меньшая цена, но по итогу они платят больше, и не особо об этом задумываются). Абонентам Смарта не хватает включенных в тариф объемов услуг и они переплачивают.
# - Подмечено два важных момента, а именно:
# - По дополнительным доходам компании - лидирует тариф Смарт с его __1 522 534__ рублей из __1 903 200__ рублей общей суммы дополнительных доходов, в тоже самое время тариф Ультра приносит больше выручки по основному доходу(абонентская плата) __60.8%__ от всей основной выручки.

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Очень подробные выводы по этому пункту - супер. Приведены общие выручки и их соотношения относительно вклада в общуую сумму. Так же выводы корректны на счет того, что тариф смарт хоть и дешевый, но данные показывают, что люди существенно переплачивают , но при этом они не тратят больше, чем клиенты ультра.
# </div>

# %% [markdown]
# Посмотрим средние значения по исползуемым минутам, смс, трафику, платежам, переплатам для общей выборки

# %%
df[['calls','minutes','sms','mb_used','age','monthly_payment','overpayment']].describe()
# Out:
#          calls  minutes      sms   mb_used      age  monthly_payment  \
# count 3,204.00 3,204.00 3,204.00  3,204.00 3,204.00         3,204.00
# mean     50.78   451.90    38.31 17,281.35    46.64         1,485.62
# std      26.97   242.01    36.19  7,528.60    16.61           784.56
# min       0.00     0.00     0.00      0.00    18.00           550.00
# 25%      32.00   285.00     9.00 12,535.75    32.00           694.00
# 50%      50.00   444.00    30.00 16,983.00    46.00         1,554.50
# 75%      66.00   589.00    57.00 21,454.25    62.00         1,950.00
# max     190.00 1,673.00   224.00 49,789.00    75.00         6,711.00
#
#        overpayment
# count     3,204.00
# mean        509.16
# std         734.52
# min           0.00
# 25%           0.00
# 50%         108.00
# 75%         841.00
# max       6,161.00

# %% [markdown]
# Видим, что людям в среднем за __один__ месяц, делают 50 звонков, выговаривают  450 минут, используют 35 смс сообщений и 17Гб трафика. Переплаты в среднем - составляют чуть больше 100 рублей.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>
#
# Добавь корректировку на то, что эти цифры необходимы клиентам именно в МЕСЯЦ.
# </div>

# %% [markdown]
# Посмотрим средние значения по исползуемым минутам, смс, трафику, платежам, переплатам для клиентов Смарт

# %%
df.query('tariff == "smart" ')[['calls','minutes','sms','mb_used','age','monthly_payment','overpayment']].describe()
# Out:
#          calls  minutes      sms   mb_used      age  monthly_payment  \
# count 2,228.00 2,228.00 2,228.00  2,228.00 2,228.00         2,228.00
# mean     46.96   418.08    33.40 16,236.47    46.55         1,233.36
# std      21.03   190.24    28.23  5,868.82    16.35           787.59
# min       0.00     0.00     0.00      0.00    18.00           550.00
# 25%      32.00   282.00    10.00 12,668.50    32.00           550.00
# 50%      47.00   422.00    28.00 16,532.00    47.00           960.00
# 75%      61.00   545.00    51.00 20,068.00    62.00         1,668.25
# max     162.00 1,435.00   143.00 38,610.00    75.00         6,711.00
#
#        overpayment
# count     2,228.00
# mean        683.36
# std         787.59
# min           0.00
# 25%           0.00
# 50%         410.00
# 75%       1,118.25
# max       6,161.00

# %% [markdown]
# Клиенты тарифа Смарт, за __один__ месяц делают в среднем 47 звонков, выговаривают 420 минут, используют около 30 смс сообщений и тратят около 16Гб трафика. Расходы на оплату услуг связи составляют в среднем 1 230 рублей  и  переплата составляет около 700 рублей

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Выводы корректны и наглядны - супер.
# </div>

# %% [markdown]
# Посмотрим средние значения по исползуемым минутам, смс, трафику, платежам, переплатам для клиентов Ультра

# %%
df.query('tariff == "ultra"')[['calls','minutes','sms','mb_used','age','monthly_payment','overpayment']].describe()
# Out:
#        calls  minutes    sms   mb_used    age  monthly_payment  overpayment
# count 976.00   976.00 976.00    976.00 976.00           976.00       976.00
# mean   59.49   529.10  49.53 19,666.59  46.84         2,061.48       111.48
# std    35.63   318.08  47.98  9,966.89  17.18           357.67       357.67
# min     0.00     0.00   0.00      0.00  18.00         1,950.00         0.00
# 25%    33.00   293.25   6.00 11,966.25  30.00         1,950.00         0.00
# 50%    59.00   520.00  38.00 19,406.00  45.00         1,950.00         0.00
# 75%    84.00   752.00  79.00 26,904.75  63.00         1,950.00         0.00
# max   190.00 1,673.00 224.00 49,789.00  75.00         4,743.00     2,793.00

# %% [markdown]
# За один календарный месяц клиенты тарифа Ультра делают в среднем около 60 звонков, выговаривают 520 минут, используют около 40 смс сообщений и тратят более 19,5 Гб трафика. Расходы на оплату услуг связи составляют в среднем 2 061 рубль, тогда как  переплата в районе 111 рублей

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Здесь так же отражается корректность в использовании и чтении методом `describe`.
# </div>

# %% [markdown]
# Создадим сводную таблицу  всех испльзуемых услуг по исследуемым тарифам.

# %%
max_services = df.pivot_table(index='tariff', values=['minutes', 'sms', 'mb_used'], aggfunc='sum')
max_services
# Out:
#          mb_used  minutes    sms
# tariff
# smart   36174853   931484  74411
# ultra   19194596   516399  48343

# %%
max_services.plot(kind='bar',figsize =(12,7),grid=True,title='Всего использованных объемов по тарифам Смарт и Ультра')
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>
#
# Такая визуализация очень не презентабельна. Попробуй отразить 3 пирога `Pie` с долевым соотношениями - будет очень наглядно.
# </div>

# %% [markdown]
# <div style="border:solid light blue 1px; padding: 1px">
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Возможно вообще не надо было это показывать, у всех разные единицы измерения. Очень наглядно,  mb_used просто - кашалот!))
#
#
# </div>

# %%
labels = 'mb_used', 'minutes', 'sms'
sizes = [36051036, 932595,74164]


fig1, ax1 = plt.subplots()
explode = (0, 0.9, 0.5) 
ax1.pie(sizes,  explode=explode, labels=labels,autopct='%1.1f%%',shadow=True, startangle=20)

 
ax1.set_title("Тариф Смарт")
plt.show()

labels = 'mb_used', 'minutes', 'sms'
sizes = [18457070, 519253, 46175]

fig1, ax1 = plt.subplots()
explode = (0, 0.9, 0.5,) 
ax1.pie(sizes, explode=explode, labels=labels,autopct='%1.1f%%',
        shadow=True, startangle=20)
ax1.set_title("Тариф Ультра")
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера V2:</b>
#
# Ты пошел в верном направлении, но было бы нагляднее если бы на одном графике были одни и те же параметры. То есть 3 параметра - 3 графика.
# </div>

# %%
max_services
# Out:
#          mb_used  minutes    sms
# tariff
# smart   36174853   931484  74411
# ultra   19194596   516399  48343

# %% [markdown]
# ***Вывод***
#
# - Пользватели тарифа Смарт переплачивают примерно 700 руб., тогда как  абонентская плата 550 руб. Клиентам  Смарта не хватает тарифного плана, и они вынужденно покупая доп. объемы - переплачивают. Основная масса переплачивает в районе 100 руб., И явному  улеличению платежей способствует покупка пакетов мегабайт(200 руб. за 1 Гб)
#
# - Что касается тарифа Ультра, то пользователем данного тарифа хватает включенных минут и смс, но по интернет трафику также заметны дополнительные заказы пакетов, но гораздо меньше чем в тарифе Смарт.
#
# - Также подмечено, что хоть мы  и имеем соотношение клиентов из тарифа __Смарт__ и __Ультра__   __70.2%__ к __29.8%__ но расходы объемов услуг варьируют  в пределах примерно __65%__ к __35%__ . Использование трафика мегабайт в тарифе Смарт __36 174 853__  /  в тарифе Ультра __19 194 596__  =  __1.88__ раза. Схожая ситуации по  минутам звонков  __931 484__ / __516 399__ = __1.8__ раза  Разница с  смс сообщениям __74 164__ / __46 175__ = __1.5__ раза

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Выводы очень хорошие, молодец. Складывается картина, что в среднем расходы у клиентов на Смарт в месяц 550+700=1250 руб. а вот у Ультра только базовый тариф стоит 1950. Хоть одни и переплачивают, но не платят больше чем другие, а пользуются столько, сколько нужно.
# </div>

# %% [markdown]
#  Для минут, смс, трафика мегабайт, посчитаем среднее, медиану, дисперсию и стандартное отклонение, для этого  создадим функцию 'indicators_and_charts' которая также помимо упомянутого выше,  будет строить гистограммы и сводить данные в таблицы.

# %%
data_smart = df.query('tariff == "smart"')
data_ultra =  df.query('tariff == "ultra"')

# %%
def indicators_and_charts(data1, data2, column, bins):
    
    mean_smart = round(data1[column].mean(), 2)
    median_smart = round(data1[column].median(), 2)
    variance_smart = (np.var(data1[column], ddof=1))
    std_smart = (np.std(data1[column], ddof=1))

    mean_ultra = data2[column].mean()
    median_ultra = (data2[column].median())
    variance_ultra = (np.var(data2[column], ddof=1))
    std_ultra = (np.std(data2[column], ddof=1))


    data = {'mean': [mean_smart, mean_ultra], 'median':[median_smart, median_ultra], 
                                       'variance': [variance_smart, variance_ultra],
                                                     'std': [std_smart, std_ultra]}
    info = pd.DataFrame(data)
    info.index = ['smart', 'ultra']
    display(info)


    fig, ax = plt.subplots(figsize=(12,7))
    

    data1.plot(y=column, kind='hist', color='blue', ax=ax, label='smart', bins=bins,
                                                             legend=True, grid=True)


    data2.plot(y=column, kind='hist', color='green', ax=ax, label='ultra', bins=bins,
                                                            legend=True, grid=True)

    plt.axvline(x=mean_smart, linewidth=2, label='Среднее smart = {}'.format(mean_smart),
                                                          color='orange', linestyle='--')

    plt.axvline(x=mean_ultra, linewidth=2, label='Среднее ultra = {}'.format(mean_ultra),
                                                            color='red', linestyle='--')

    plt.legend(loc='upper right')
    plt.title('Гистограмма ' + column + ' по тарифам')

    plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Отдельный плюсик за сокращение своих действия с помощью создания функций. Дам немного советов по оптимизации:
#
# 1. Зачем, ты разбиваешь отдельно две выборки для двух тарифов, еще и отдельно для каждой считаешь свои параметры, потом собираешь датафреймы на их основе? Можно сделать немного проще. Собери все в один датафрейм:
#
# ```python
# statistics = df.groupby('tariff')[['minutes'
#                                    , 'sms'
#                                    , 'mb_used'
#                                    , 'monthly_payment']].agg(['mean'
#                                                               , 'median'
#                                                               , 'var'
#                                                               , 'std'])
# ```
# Будет что-то вроде:
# <img src=https://ic.wampi.ru/2021/06/01/image02616a3413d28d66.png width="900">
# Пока не совсем презентабельно, но нам этого и не требуется, смотри, теперь к нему обращаться будет очень просто. Нужно среднее у смарт по звонкам обращаешься к `statistics`:
#
# ```python
# statistics.loc['smart', ('minutes', 'mean')]
# ```
# Нужно отобразить часть, где только минуты? Прописываешь:
#
# ```python
# display(statistics.loc[:, 'minutes'])
# ```
# И будет тебе счастье. В итоге нужна одна строка кода с группировкой вместо 12 твоих промежуточных для подсчета каждого параметра и формирования дф на их основе.
# </div>

# %% [markdown]
# <div style="border:solid light blue 1px; padding: 1px">
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
#  Хорошо, беру в арсенал - Спасибо!
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера V2:</b>
#
# 😉
# </div>

# %% [markdown]
# Результаты  по минутам.

# %%
indicators_and_charts(data_smart, data_ultra, 'minutes', 100)
# Out:
#         mean  median   variance    std
# smart 418.08  422.00  36,190.08 190.24
# ultra 529.10  520.00 101,172.28 318.08

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# График отличный. Все подписи присутствуют, легенда есть, масштаб подобран корректно.
# </div>

# %% [markdown]
# Значения средних и медиан схожи, получилось нормальное распределение. Заметно не значительное превышение среднего по тарифу Ультра над средним по тарифу Смарт.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>
#
# Попропуй оценить дисперсию и отклонения, по гистограмме можно это сделать?
#
# </div>

# %% [markdown]
# <div style="border:solid light blue 1px; padding: 1px">
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
#  Не совсем понял вопрос. На графике найти дисперсию или корень от нее? В общем,то что я понял, думаю нет, не возможно. Если среднее можно описать функцианальной зависимостью двух переменных(количество от цены). То здесь, сложные квадратичные расчеты, вон Numpy даже вызвали. Да и в теории не показывали таких чудес, было правда, что зная стандартное отклонение, а это корень из дисперсии, можно на графике определить  нормальное распределение. Верно правило трёх стандартных отклонений, или правило трёх сигм. Оно гласит — практически все значения (около 99%) находятся в промежутке:  (μ−3σ,μ+3σ) Но сами значения σ и s может Numpy описать и то если только правильные ему задать параметры. Возможно заблуждаюсь не знаяю.
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера V2:</b>
#
# Ушел ты конечно в хардкорные статистические дебри. Вопрос немного попроще, чем ты его понял. У тебя на одном графике распределения длительности минут по обоим тарифам. Со средними понятно, одно больше, другое меньше. А можно ли как-то оценить отклонения и дисперсию?
#
# Ты верно подметил, что это два связанных параметра, один равен квадрату другого - гуд. Тогда остается вопрос, а можно ли оценить либо дисперсию, либо отклонения? Именно ОЦЕНИТЬ, а не ПОДСЧИТАТЬ. А ответ будет такой - да, можно. Один график существенно шире другого, значит дисперсия этой выборки больше, чем другой.
#
# Про подсчет параметров можешь почитать в теории, на самом деле эти величины вычисляются не так сложно.
#
# </div>

# %% [markdown]
# Результаты  по смс.

# %%
indicators_and_charts(data_smart, data_ultra, 'sms', 37)
# Out:
#        mean  median  variance   std
# smart 33.40   28.00    796.73 28.23
# ultra 49.53   38.00  2,302.38 47.98

# %% [markdown]
# В обоих тарифах просматриваются высокие пики около 0 это свидетельствует о падении популярности смс.Медиана меньше среднего, распределение смещено вправо. Здесь также наблюдаестя не значительное превышение среднего по тарифу Ультра

# %% [markdown]
# Результаты  по трафику Мегабайт.

# %%
indicators_and_charts(data_smart, data_ultra, 'mb_used', 37)
# Out:
#            mean    median      variance      std
# smart 16,236.47 16,532.00 34,443,083.87 5,868.82
# ultra 19,666.59 19,406.00 99,338,950.79 9,966.89

# %% [markdown]
# Среднее значение тарифа Ультра также превышает значение тарифа Смарт. Значения средних и медиан по тарифам схожи. Наблюдается нормальное  распределение.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Все гистограммы отличные, визуализация на высоком уровне.
# </div>

# %% [markdown]
# Построим диаграммы рассеяния для тарифов Смарт и Ультра:

# %%
data_matrix = df.loc[:,['mb_used','sms','minutes','monthly_payment']]#количественные переменные которые будуд в корреляционной матрице

# %%
pd.plotting.scatter_matrix(data_matrix, figsize=(14, 14))#посмотрим корреляцию через график
plt.show()

# %% [markdown]
# Выделим отлельно показания корреляции по тарифу Смарт

# %%
data_smart_matrix = data_smart.loc[:,['mb_used','sms','minutes','monthly_payment']]#количественные переменные которые будуд в корреляционной матрице

# %%
pd.plotting.scatter_matrix(data_smart_matrix, figsize=(14, 14))#посмотрим корреляцию через график
plt.show()

# %%
corrMatrix = data_smart_matrix.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()

# %% [markdown]
# Месячная плата на тарифе Смарт определяется, в основном, покупкой пакетов трафика сверх лимита, и немного меньше, минутами звонков, выходящими за лимит.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# С выводами согласен. Отличная визулиацзия и наглядные выводы.
# </div>

# %% [markdown]
# Выделим отлельно показания корреляции по тарифу Ультра

# %%
data_ultra_matrix = data_ultra.loc[:,['mb_used','sms','minutes','monthly_payment']]#количественные переменные которые будуд в корреляционной матрице

# %%
pd.plotting.scatter_matrix(data_ultra_matrix, figsize=(14, 14))#посмотрим корреляцию через график
plt.show()

# %%
corrMatrix = data_ultra_matrix.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()

# %% [markdown]
# Месячная плата на тарифе Ультра также  определяется, покупкой пакетов трафика сверх лимита, но уже меньше, а смс и минут разговора хватает из включенных в тарифный план.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Да, в этом случае наблюдаются небольшие различия от тарифа Смарт.
# </div>

# %% [markdown]
#  На тарифе **Ультра** происходит увеличение месячной платы после использования 30 Гб трафика, с минутами такого не наблюдается.  В тарифе **Смарт**  повышение палаты происходит после использования 15 Гб трафика и 500 минут разговора, что согласуется с условиям тарифных планов.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# ***Вывод:***
#
#
# - Тариф Смарт изначально привлекает ценой абонентской платы(550 рублей),  по факту же  пользователи данного тарифа переплачивают так как не укладываются в выделенные в тарифе пакеты. И если переплаты за  минуты и смс умеренные, то платежы за пакеты мегабайт очень весомые(200 рублей 1Гб тариф Смарт и 150 рублей в тарифе Ультра). Прослеживается явная тенденция к уменьшению звонков и отправки смс, но люди не стали общаться меньше, скорее наоборот. Этому способствует появление всевозможных Мессенджеров и приложений - дающих альтернативу в выборе, но для пользования этими альтернативами необходим интернет трафик,  и  эта потребность  явно прослеживается из наблюдений.  15 Мб по нынешним меркам уже  не достаточно, отсюда и такие переплаты.
#
# * Что касается расходов пользователей тарифа Ультра, то здесь ситуации более уравновешена. Практически всем пользователям хватает выделенных в базовом тарифе минут и смс, есть переплаты за интернет трафик, но в сравнении с тарифом Смарт они не велики.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Вывод подробный и информативный, ты отлично прочитал и проанализировал сгруппированные данные.
# </div>

# %% [markdown]
# ## Проверка гипотез.
# [&#10224;](#step1)

# %% [markdown]
#  <div style="border:solid green 2px; padding: 20px">
#
# ## Проверим следующие гипотезы<a class="tocSkip">
#
# - средняя выручка пользователей тарифов «Ультра» и «Смарт» различается;
# - средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов;
#
# Сформируем нудевую  и альтернативную гипотезы:
#
# * Н0: средняя выручка от клиентов тарифа **Ультра** не отличается от клиентов тарифа **Смарт**;
# * Н1: средняя выручка от клиентов тарифа **Ультра** отличается от клиентов тарифа **Смарт**.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Отлично, что выделяешь все формулировки. Только нужно было тогда нулевую и альтернативную прописывать для обеих гипотез, а не только для одной в рамочке.
# </div>

# %%
from scipy import stats as st

alpha = 0.05
result = st.ttest_ind(data_smart['monthly_payment'], data_ultra['monthly_payment'],
                                                                   equal_var=False)

print('p-значение = ', result.pvalue)

if result.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
    
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение =  8.415059043575043e-295
# Отвергаем нулевую гипотезу

# %% [markdown]
# Можно утверждать, что есть отличие в средней выручке между тарифами Смарт и Ультра.

# %% [markdown]
# Посмотрим на статестическую значимость. Получим средние выручки по тарифам Смарт и Ультра

# %% [markdown]
# Средняя выручка по тарифному плану Смарт

# %%
data_smart['monthly_payment'].mean()
# Out:
# 1233.3635547576303

# %% [markdown]
# Средняя выручка по тарифному плану Ультра

# %%
data_ultra['monthly_payment'].mean()
# Out:
# 2061.4815573770493

# %% [markdown]
# Видим разницу __1.67__ раза  в средней выручке между тарифом Ультра и Смарт. Не удивительно, что средняя выручка по тарифному плану Ультра выше, обусловлено это разницей __3.5__ раза  в платежах по абонентской плате. Напомним абонентская плата по тарифу Ультра - 1950 руб/месяц, тогда как по тарифу Смарт всего 550 руб/месяц.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Вывод по 1-ой гипотезе корректен, проверка так же произведена и вывод подтвержден.
# </div>

# %% [markdown]
# На данном этапе  проверим гипотезу о том, что средняя выручка пользователей из Москвы отличается от выручки пользователей из  регионов. Сформулируем нулевую и альтернативную гипотезу:
#
# * Н0: средняя выручка от клиентов из Москвы не отличается от средней выручки от клиентов из других регионов;
# * Н1: средняя выручка от клиентов из Москвы отличается от средней выручки от клиентов из других регионов.

# %% [markdown]
# Создадим срезы по Москве и региону отдельно

# %%
data_moscow = df.query('city =="Москва"')
data_moscow.head(2)
# Out:
#    user_id  age churn_date    city first_name last_name   reg_date tariff  \
# 8     1001   41        NaT  Москва       Иван      Ежов 2018-11-01  smart
# 9     1001   41        NaT  Москва       Иван      Ежов 2018-11-01  smart
#
#    messages_included  mb_per_month_included  minutes_included  \
# 8                 50                  15360               500
# 9                 50                  15360               500
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute  mb_used  \
# 8              550         200                3               3    14053
# 9              550         200                3               3    18452
#
#    calls  minutes  sms  monthly_payment  overpayment  not_over
# 8     47      414    0              550            0       550
# 9     45      430    0             1153          603       550

# %%
data_regions = df.query('city !="Москва"')
data_regions.head(2)
# Out:
#    user_id  age churn_date       city first_name  last_name   reg_date tariff  \
# 0     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 1     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
#
#    messages_included  mb_per_month_included  minutes_included  \
# 0               1000                  30720              3000
# 1               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute  mb_used  \
# 0             1950         150                1               1    14070
# 1             1950         150                1               1     9827
#
#    calls  minutes  sms  monthly_payment  overpayment  not_over
# 0     42      408   81             1950            0      1950
# 1     38      333   70             1950            0      1950

# %% [markdown]
# Проверим  гипотезу (Средняя выручка по Москве отличается от средней выручки по регионам)

# %%
alpha = 0.05
result = st.ttest_ind(data_moscow['monthly_payment'], data_regions['monthly_payment'],
                                                                   equal_var=False)

print('p-значение = ', result.pvalue)

if result.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
    
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение =  0.43262166405450475
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Полученный результат говорит о том, что средняя выручка от клиентов из Москвф не отличается от средней выручки от клиентов из других регионов. Отвергнуть нулевую гипотезу - не удалось.

# %% [markdown]
# Также посмотрим на статистическую значимость. Получим средние выручки по Москве  и регионам

# %% [markdown]
# Средняя выручка по Москве

# %%
data_moscow['monthly_payment'].mean()
# Out:
# 1507.0671031096563

# %% [markdown]
# Средняя выручка по регионам

# %%
data_regions['monthly_payment'].mean()
# Out:
# 1480.5715387581952

# %% [markdown]
# Из сравнения средних показателей выручки по клиентам из Москвы и регионам получили разницу в районе 27 рублей. Т.е. средние показатели по выручке говорт о том, что клиенты из Москвы платять на 27 рублей больше чем клиенты из регионов.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Действительно, вторая гипотеза так же проверена верно и выручка в среднем одинакова.
# </div>

# %% [markdown]
# ## Общий вывод
# [&#10224;](#step1)

# %%
users_tariff# количественное соотношение клиентов Смарт и Ультра
# Out:
#        tariff
# smart     351
# ultra     149

# %%
 percent_tariffs# процентное соотношение по клиентам Смарт и Ультра
# Out:
#        tariff
# smart   70.20
# ultra   29.80

# %%
services # суммарные показатели по ключевым позициям
# Out:
#          calls   mb_used  minutes  monthly_payment  not_over  overpayment  \
# tariff
# smart   104637  36174853   931484          2747934   1225400      1522534
# ultra    58066  19194596   516399          2012006   1903200       108806
#
#           sms
# tariff
# smart   74411
# ultra   48343

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Было бы оптимальней объединить все три блока выше в один и вывести его с разными `style` для датафрейма, например:
#
# ```python
# pd.concat([users_tariff.rename(columns={'tariff':'count_clients'})
#            , percent_tariffs.rename(columns={'tariff':'%_clients'})
#            , services], axis=1).style.bar(subset=a.columns[:2], color='lightgreen')\
#                                      .bar(subset=a.columns[2:], color='#ee1f5f')
# ```
# Будет что-то вроде:
# <img src=https://ic.wampi.ru/2021/06/02/image.png width="900">
# </div>

# %%
pay = [df['monthly_payment'] ,df['not_over'], df['overpayment']]
for i in pay:
    display(i.sum())# для корректировки цифр в выводах
    
a = pd.concat([users_tariff.rename(columns={'tariff':'count_clients'})
               , percent_tariffs.rename(columns={'tariff':'%_clients'})
               , services], axis=1)

a.style.bar(subset=a.columns[:2], color='lightgreen')\
       .bar(subset=a.columns[2:], color='#ee1f5f')
# Out:
# 4759940
# 3128600
# 1631340
# <style  type="text/css" >
# #T_60c64f6b_c47a_11eb_b49d_aced5ccfe2bfrow0_col0,#T_60c64f6b_c47a_11eb_b49d_aced5ccfe2bfrow0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
#         }#T_60c64f6b_c47a_11eb_b49d_aced5ccfe2bfrow0_col2,#T_60c64f6b_c47a_11eb_b49d_aced5ccfe2bfrow0_col3,#T_60c64f6b_c47a_11eb_b49d_aced5ccfe2bfrow0_col4,#T_60c64f6b_c47a_11eb_b49d_aced5ccfe2bfrow0_col5,#T_60c64f6b_c47a_11eb_b49d_aced5ccfe2bfrow0_col7,#T_60c64f6b_c47a_11eb_b49d_aced5ccfe2bfrow0_col8,#T_60c64f6b_c47a_11eb_b49d_aced5ccfe2bfrow1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 100.0%, transparent 100.0%);
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# аа, я вообщем, когда тебе этот пример сооружал, то в `subset=a.columns[:2]` поместил колонки промежуточного датафрейма, а потом убрал его присвоение, теперь будет работать:
#
# ```python
# a = pd.concat([users_tariff.rename(columns={'tariff':'count_clients'})
#                , percent_tariffs.rename(columns={'tariff':'%_clients'})
#                , services], axis=1)
#
# a.style.bar(subset=a.columns[:2], color='lightgreen')\
#        .bar(subset=a.columns[2:], color='#ee1f5f')
# ```
# </div>

# %% [markdown]
# <div style="border:solid light blue 1px; padding: 1px">
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
#  Спасибо, классно получается ! Можно и другие процентные и количественные соотношения отражать. Жаль только вот стиль брыкается, возможно какойто библиотеки не хватает(.
# </div>

# %% [markdown]
#  <div style="border:solid green 2px; padding: 20px">
#
#  Общий доход компании 'Мегаланй' за год составляет __4 759 940__ рублей. Из них __3 128 600__ рублей это поступления от основного дохода (абонентская плата) и  __1 631 340__ рублей от дополнительных платежей за перерасходованные включенные в основной пакет услуги.
#
#
#  Тарифа __Смарт__ пользуется большей популярностью составляют 70,2% всех клиентов из исследуемой выборки, приносит общий доход компании 'Мегалайн ' в размере  __2 747 934__ рублей годовой выручки, что в свою очередь составляет __57.7%%__ от всех поступлений. Также данный тариф лидирует по суммам приносимым компании от дополнительных платежей за перерасходованные пакеты включенные в абонентскую плату. Сумма дополнительных поступлений составляет __1 522 534__ рублей, что в свою очередь составляет __93.3%__ от всех  поступлений всязанных с перерасходом по основным пакетам услуг. В тоже самое время наблюдается меньшая выручка по основным платежам (абонентская плата), она составляет __1 225 400__ рублей и это __39.2%__ от основных платежей. По используемым услугам тариф Смарт лидирует практически с 2-х разовым отрывом от тарифа Ультра. Это можно объяснить больших количесвом абонентов  в тарифе Смарт. Было замечено, что абоненты данного тарифа ежемесячно в среднем переплачивают порядка 700 рублей это больше самой абоненткой платы! Они практически полностью расходуют лимиты тарифа на минуты, очень активно пользуются интернетом, что приводит к перерасходу выделеных в рамках тарифа 15Гб трафика. Среднее использование интернет трафика в тарифе Смарт достигает 17Гб, что приводит к выходу за лемит на 2Гб и так как стоимость доп. Гб составляет 200 рублей, то переплаты только за интернет в среднем   достигают 400 рублей в месяц.
#
#
#  Тариф __Ультра__ менее популярен(29.8%), видимо людей отпугивает сумма абонентской платы (1950 рублей) которая превышает   абонентскую плату по тарифу __Смат__ практически в __3.5__ раза. Показатели по общей выручке здесь уступают тарифу Смрт - __2 012 006__ рублей это составляет__42.3%__ от всей выручки компании. По дополнительным доходам тариф Ультра приносит всего __6.7%__  в денежном измерении это __108 806__ рублей, зато по основным платежам (абонентская плата) является лидером и приносит __60.8%__ поступлений от основных платежей и составляет  __1 903 200__ рублей. В тарифе Ультра практически все пользователи укладываются в пакеты услуг по минутам и смс сообщениям, что нельзя сказать об интернет трафике, здесь также как  и в тарифе Смарт людям не хватает мегабайт, но эта нехватка просматривается не так ярко. Пользователи тарифа Ультра более активно пользуются интернетом и их средний расход трафика составляет в среднем порядка 19.55 Гб
#
#   Средняя выручка от одного  клиента составляет:           (4 759 940 / 500) / 12 =  __793__ рубля.<br>
#   Средний выручка от одного клиента __Смарт__  составляет: (2 747 934 / 351) / 12 =  __652__ рубля.<br>
#   Средний выручка от одного клиента __Ультра__ составляет: (2 012 006 / 149) / 12 =  __1 125__ рубля.<br>
#
#
# Рекомендации для компании Мегалайн
#
#
# После проведения исследования данной выборки и получения определенных выводов, можно рекомендовать коммерческому департаменту компании 'Мегалайн' обратить внимание на следующие обнаруженные в анализе особенности:
#
#    - неудержимое проникновение интернет трафик в во все сферы человеческой жизни-деятельности и как следствие вытеснение других менее удобных для пользования услуг. Это четко просматривается на предпочтениях пользователей и  отдаче пердпочтения интернету  относительно голосовой связи и тем более смс сообщений.  Здесь можно рекомендовать более пристально посмотреть на перспективы развития интернета, и с должным внимание отнестись к улучшению, как самой связи передачи данных, так и удобства для клиентов при использовании интернет трафика.(вариантность, расщиренная линейка, отдельный тариф интернет)
#
#    - также, обратив внимани, что средняя выручка по тарифу Ультра больше чем по тарифу Смарт, но большая  абонентская плата, заставляет отдавать предпочтение тарифу Смарт можно рекомендовать расширить линейку тарифных планов, создав нечто среднее между Ультра и Смарт. Тарифе Смарт средняя переплата составляет больше половины абонентской платы 700 рублей что в итоге приводит к платежам в размере 1250 рублей в месяц, значит люди смогут платить за новый  тариф в районе 1000 рублей. Также еще раз упомянем о перспективном развитии интернет связи, стоит уделить этому отдельное внимание в виде создания отдельных предложений связанных с данны  видом связи. Введение дополнительных тарифов, позволит более тонко клиентам подстраиваться под свои потребности, это в свою очередь добавить конкурентных приемуществ и  усилит позиции компании 'Мегалай' на рынке мобильной связи.
#
#
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Вывод исчерпывающий и образцово-показательный, ты привел локаничные и понятные рассуждения по всем пунктам своего анализа, максимально подробно расписал свои действия и сложил пазл в итоговом выводе. Супер.
# </div>

# %% [markdown]
# ---

# %% [markdown]
# <a id='step20'></a>

# %% [markdown]
#  <div style="border:solid green 2px; padding: 20px">
#
# ___Описание проекта___
# [&#10224;](#step2)
#
#
# Вы аналитик компании «Мегалайн» — федерального оператора сотовой связи. Клиентам предлагают два тарифных плана: «Смарт» и «Ультра». Чтобы скорректировать рекламный бюджет, коммерческий департамент хочет понять, <font color='red'>какой тариф приносит больше денег.</font>
# Вам предстоит сделать предварительный анализ тарифов на небольшой выборке клиентов. В вашем распоряжении данные 500 пользователей «Мегалайна»:<font color='red'> кто они, откуда, каким тарифом пользуются, сколько звонков и сообщений каждый отправил за 2018 год.</font> Нужно проанализировать поведение клиентов и сделать вывод — <font color='red'>какой тариф лучше.</font>
#
#
#
#
# ***Инструкция по выполнению проекта***<br>
# - ***Шаг 1. Откройте файл с данными и изучите общую информацию***
#  Скачать датасет
# - ***Шаг 2. Подготовьте данные***
# - **Приведите данные к нужным типам;**
# - Найдите и исправьте ошибки в данных.
# Поясните, какие ошибки вы нашли и как их исправили. Обратите внимание, что длительность многих звонков — 0.0 минут. Это могут быть пропущенные звонки. Обрабатывать ли эти нулевые значения, решать вам — оцените, как их отсутствие повлияет на результаты анализа.<br>
# **Посчитайте для каждого пользователя:**<br>
# - количество сделанных звонков и израсходованных минут разговора по месяцам;
# - количество отправленных сообщений по месяцам;
# - объем израсходованного интернет-трафика по месяцам;
# - помесячную выручку с каждого пользователя (вычтите бесплатный лимит из суммарного количества звонков, сообщений и интернет-
# трафика; остаток умножьте на значение из тарифного плана; прибавьте абонентскую плату, соответствующую тарифному плану).
# - ***Шаг 3. Проанализируйте данные***
# Опишите поведение клиентов оператора, исходя из выборки. Сколько минут разговора, сколько сообщений и какой объём интернет-трафика требуется пользователям каждого тарифа в месяц? Посчитайте среднее количество, дисперсию и стандартное отклонение. Постройте гистограммы. Опишите распределения.
# - ***Шаг 4. Проверьте гипотезы***<br>
# - <font color='green'>средняя выручка пользователей тарифов «Ультра» и «Смарт» различается;</font>
# - <font color='green'>средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов;</font><br>
# Пороговое значение alpha задайте самостоятельно.
# Поясните:
# как вы формулировали нулевую и альтернативную гипотезы;
# какой критерий использовали для проверки гипотез и почему.
#
#
#
#
#
#
#
#
#
# ***Описание данных*** <br>
#
# `1.Таблица` ___users___ — (информация о пользователях):
# - **tariff_name** — название тарифа
# - **user_id** — уникальный идентификатор пользователя
# - **first_name** — имя пользователя
# - **last_name** — фамилия пользователя
# - **age — возраст** пользователя (годы)
# - **reg_date** — дата подключения тарифа (день, месяц, год)
# - **churn_date** — дата прекращ пользован тарифом (если значение пропущено, то тариф ещё действовал на момент выгрузки данных)
# - **city** — город проживания пользователя
# - **tariff** — название тарифного плана<br>
#
# `2.Таблица` ____calls____ — (информация о звонках):<br>
# - **id** — уникальный номер звонка
# - **call_date** — дата звонка
# - **duration** — длительность звонка в минутах
# - **user_id** — идентификатор пользователя, сделавшего звонок<br>
#
# `3.Таблица` ___messages___ — (информация о сообщениях):<br>
# - **id** — уникальный номер сообщения
# - **message_date** — дата сообщения
# - **user_id** — идентификатор пользователя, отправившего сообщение<br>
#
# `4.Таблица` ___internet___ — (информация об интернет-сессиях):<br>
# - **id** — уникальный номер сессии
# - **mb_used** — объём потраченного за сессию интернет-трафика (в мегабайтах)
# - **session_date** — дата интернет-сессии
# - **user_id** — идентификатор пользователя<br>
#
# `5.Таблица` ___tariffs___ — (информация о тарифах):
# - **tariff_name** — название тарифа
# - **rub_monthly_fee** — ежемесячная абонентская плата в рублях
# - **minutes_included** — количество минут разговора в месяц, включённых в абонентскую плату
# - **messages_included** — количество сообщений в месяц, включённых в абонентскую плату
# - **mb_per_month_included** — объём интернет-трафика, включённого в абонентскую плату (в мегабайтах)
# - **rub_per_minute** — стоимость минуты разговора сверх тарифного пакета (например, если в тарифе 100 минут разговора в месяц, то со 101 минуты будет взиматься плата)
# - **rub_per_message** — стоимость отправки сообщения сверх тарифного пакета
# - **rub_per_gb** — стоимость дополнительного гигабайта интернет-трафика сверх тарифного пакета (1 гигабайт = 1024 мегабайта)
#
#     <br>   __Примечание__. Если объединение таблиц методом merge приводит к ошибке dead kernell, примените метод join — это облегчит нагрузку на Jupyter Notebook.

# %% [markdown]
# #    <br>[**В начало**](#step1)
